# %%
import pandas as pd
from tqdm.notebook import tqdm
import seaborn as sns

from hu_nmt.data_augmentator.translate.translate import get_translator
from hu_nmt.data_augmentator.utils.cosine_similarity import get_model, get_word_average_cos_similarity, get_sentence_embedding_cos_similarity

sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.set_style("whitegrid")

# %%
batch_size = 512

# %%
huen_translator = get_translator(
    model_path='/home1/hu-nmt/patrick/opennmt/experiments/runs/huen-poc/run/model.pt',
    sp_model_path='/home1/hu-nmt/data/Hunglish2/combined-32-simple/sp_models/spm_huen.model',
    batch_size=batch_size)
enhu_translator = get_translator(
    model_path='/home1/hu-nmt/patrick/opennmt/experiments/runs/enhu-poc/run/model.pt',
    sp_model_path='/home1/hu-nmt/data/Hunglish2/combined-32-simple/sp_models/spm_huen.model',
    batch_size=batch_size)
# Out:
# [2021-11-12 18:30:30,810 INFO] Using model: ['/home1/hu-nmt/patrick/opennmt/experiments/runs/huen-poc/run/model.pt']
# [2021-11-12 18:30:30,815 INFO] Using sentencepiece model: /home1/hu-nmt/data/Hunglish2/combined-32-simple/sp_models/spm_huen.model
# [2021-11-12 18:30:36,891 INFO] Using model: ['/home1/hu-nmt/patrick/opennmt/experiments/runs/enhu-poc/run/model.pt']
# [2021-11-12 18:30:36,893 INFO] Using sentencepiece model: /home1/hu-nmt/data/Hunglish2/combined-32-simple/sp_models/spm_huen.model

# %%
data_path = '/home1/hu-nmt/data/Hunglish2/augmented/generated-0.25/obj_swapping'

# %%
import os

eng_path = os.path.join(data_path, 'obj_swapping.en')
hun_path = os.path.join(data_path, 'obj_swapping.hu')

# %%
en_embedding_model = get_model('en')
hu_embedding_model = get_model('hu')
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
huen_similarity_scores, enhu_similarity_scores = [], []
hun_lines, eng_lines = [], []
translated_hun_lines, translated_eng_lines = [], []
with open(hun_path, 'r') as hun_file:
    with open(eng_path, 'r') as eng_file:
        for i, (hun_line, eng_line) in tqdm(enumerate(zip(hun_file, eng_file))):
            hun_lines.append(hun_line.strip())
            eng_lines.append(eng_line.strip())
            
            if len(hun_lines) % batch_size == 0:
                # translate lines
                translated_eng_lines.extend(huen_translator.translate(hun_lines[-batch_size:]))
                translated_hun_lines.extend(enhu_translator.translate(eng_lines[-batch_size:]))
            
                # check similarity
                huen_scores = [get_sentence_embedding_cos_similarity(eng_line, translated_eng_line, en_embedding_model) for eng_line, translated_eng_line in zip(eng_lines[-batch_size:], translated_eng_lines[-batch_size:])]
                enhu_scores = [get_sentence_embedding_cos_similarity(hun_line, translated_hun_line, hu_embedding_model) for hun_line, translated_hun_line in zip(hun_lines[-batch_size:], translated_hun_lines[-batch_size:])]
            
                # save result
                huen_similarity_scores.extend([score[0][0] for score in huen_scores])
                enhu_similarity_scores.extend([score[0][0] for score in enhu_scores])
                
        last_batch_size = len(hun_lines) - (int(len(hun_lines) / batch_size) * batch_size)
        
        # translate lines
        translated_eng_lines.extend(huen_translator.translate(hun_lines[-last_batch_size:]))
        translated_hun_lines.extend(enhu_translator.translate(eng_lines[-last_batch_size:]))

        # check similarity
        huen_scores = [get_sentence_embedding_cos_similarity(eng_line, translated_eng_line, en_embedding_model) for eng_line, translated_eng_line in zip(eng_lines[-last_batch_size:], translated_eng_lines[-last_batch_size:])]
        enhu_scores = [get_sentence_embedding_cos_similarity(hun_line, translated_hun_line, hu_embedding_model) for hun_line, translated_hun_line in zip(hun_lines[-last_batch_size:], translated_hun_lines[-last_batch_size:])]

        # save result
        huen_similarity_scores.extend([score[0][0] for score in huen_scores])
        enhu_similarity_scores.extend([score[0][0] for score in enhu_scores])
# Out:
# 0it [00:00, ?it/s]
# [2021-11-12 21:07:25,922 INFO] Translating shard 0.
# [2021-11-12 21:07:27,967 INFO] PRED AVG SCORE: -0.5174, PRED PPL: 1.6776
# [2021-11-12 21:07:27,988 INFO] Translating shard 0.
# [2021-11-12 21:07:29,866 INFO] PRED AVG SCORE: -0.7053, PRED PPL: 2.0244
# [2021-11-12 21:07:30,290 INFO] Translating shard 0.
# [2021-11-12 21:07:32,201 INFO] PRED AVG SCORE: -0.5342, PRED PPL: 1.7061
# [2021-11-12 21:07:32,213 INFO] Translating shard 0.
# [2021-11-12 21:07:34,178 INFO] PRED AVG SCORE: -0.7214, PRED PPL: 2.0573
# [2021-11-12 21:07:34,554 INFO] Translating shard 0.
# [2021-11-12 21:07:36,537 INFO] PRED AVG SCORE: -0.5136, PRED PPL: 1.6713
# [2021-11-12 21:07:36,548 INFO] Translating shard 0.
# [2021-11-12 21:07:38,648 INFO] PRED AVG SCORE: -0.7323, PRED PPL: 2.0798
# [2021-11-12 21:07:39,005 INFO] Translating shard 0.
# [2021-11-12 21:07:40,821 INFO] PRED AVG SCORE: -0.5093, PRED PPL: 1.6642
# [2021-11-12 21:07:40,835 INFO] Translating shard 0.
# [2021-11-12 21:07:42,929 INFO] PRED AVG SCORE: -0.7201, PRED PPL: 2.0547
# [2021-11-12 21:07:43,285 INFO] Translating shard 0.
# [2021-11-12 21:07:45,033 INFO] PRED AVG SCORE: -0.5254, PRED PPL: 1.6911
# [2021-11-12 21:07:45,044 INFO] Translating shard 0.
# [2021-11-12 21:07:47,248 INFO] PRED AVG SCORE: -0.7225, PRED PPL: 2.0596
# [2021-11-12 21:07:47,643 INFO] Translating shard 0.
# [2021-11-12 21:07:49,746 INFO] PRED AVG SCORE: -0.5134, PRED PPL: 1.6709
# [2021-11-12 21:07:49,757 INFO] Translating shard 0.
# [2021-11-12 21:07:52,159 INFO] PRED AVG SCORE: -0.7095, PRED PPL: 2.0330
# [2021-11-12 21:07:52,558 INFO] Translating shard 0.
# [2021-11-12 21:07:54,574 INFO] PRED AVG SCORE: -0.5059, PRED PPL: 1.6585
# [2021-11-12 21:07:54,588 INFO] Translating shard 0.
# [2021-11-12 21:07:56,589 INFO] PRED AVG SCORE: -0.7063, PRED PPL: 2.0265
# [2021-11-12 21:07:56,949 INFO] Translating shard 0.
# [2021-11-12 21:07:58,726 INFO] PRED AVG SCORE: -0.5150, PRED PPL: 1.6737
# [2021-11-12 21:07:58,737 INFO] Translating shard 0.
# [2021-11-12 21:08:00,806 INFO] PRED AVG SCORE: -0.7193, PRED PPL: 2.0530
# [2021-11-12 21:08:01,143 INFO] Translating shard 0.
# [2021-11-12 21:08:02,828 INFO] PRED AVG SCORE: -0.5058, PRED PPL: 1.6583
# [2021-11-12 21:08:02,839 INFO] Translating shard 0.
# [2021-11-12 21:08:04,732 INFO] PRED AVG SCORE: -0.7200, PRED PPL: 2.0544
# [2021-11-12 21:08:05,087 INFO] Translating shard 0.
# [2021-11-12 21:08:06,891 INFO] PRED AVG SCORE: -0.5190, PRED PPL: 1.6804
# [2021-11-12 21:08:06,903 INFO] Translating shard 0.
# [2021-11-12 21:08:09,220 INFO] PRED AVG SCORE: -0.7152, PRED PPL: 2.0446
# [2021-11-12 21:08:09,579 INFO] Translating shard 0.
# [2021-11-12 21:08:11,537 INFO] PRED AVG SCORE: -0.5161, PRED PPL: 1.6755
# [2021-11-12 21:08:11,548 INFO] Translating shard 0.
# [2021-11-12 21:08:13,658 INFO] PRED AVG SCORE: -0.7007, PRED PPL: 2.0152
# [2021-11-12 21:08:14,021 INFO] Translating shard 0.
# [2021-11-12 21:08:16,076 INFO] PRED AVG SCORE: -0.5104, PRED PPL: 1.6660
# [2021-11-12 21:08:16,088 INFO] Translating shard 0.
# [2021-11-12 21:08:21,954 INFO] PRED AVG SCORE: -0.7136, PRED PPL: 2.0413
# [2021-11-12 21:08:22,298 INFO] Translating shard 0.
# [2021-11-12 21:08:24,184 INFO] PRED AVG SCORE: -0.5176, PRED PPL: 1.6780
# [2021-11-12 21:08:24,195 INFO] Translating shard 0.
# [2021-11-12 21:08:26,129 INFO] PRED AVG SCORE: -0.7188, PRED PPL: 2.0521
# [2021-11-12 21:08:26,489 INFO] Translating shard 0.
# [2021-11-12 21:08:28,269 INFO] PRED AVG SCORE: -0.5331, PRED PPL: 1.7042
# [2021-11-12 21:08:28,281 INFO] Translating shard 0.
# [2021-11-12 21:08:30,213 INFO] PRED AVG SCORE: -0.7102, PRED PPL: 2.0343
# [2021-11-12 21:08:30,545 INFO] Translating shard 0.
# [2021-11-12 21:08:32,221 INFO] PRED AVG SCORE: -0.5360, PRED PPL: 1.7091
# [2021-11-12 21:08:32,233 INFO] Translating shard 0.
# [2021-11-12 21:08:34,026 INFO] PRED AVG SCORE: -0.7213, PRED PPL: 2.0570
# [2021-11-12 21:08:34,429 INFO] Translating shard 0.
# [2021-11-12 21:08:36,445 INFO] PRED AVG SCORE: -0.5000, PRED PPL: 1.6487
# [2021-11-12 21:08:36,456 INFO] Translating shard 0.
# [2021-11-12 21:08:38,493 INFO] PRED AVG SCORE: -0.7018, PRED PPL: 2.0174
# [2021-11-12 21:08:38,874 INFO] Translating shard 0.
# [2021-11-12 21:08:41,084 INFO] PRED AVG SCORE: -0.5137, PRED PPL: 1.6714
# [2021-11-12 21:08:41,096 INFO] Translating shard 0.
# [2021-11-12 21:08:43,198 INFO] PRED AVG SCORE: -0.7113, PRED PPL: 2.0366
# [2021-11-12 21:08:43,568 INFO] Translating shard 0.
# [2021-11-12 21:08:45,221 INFO] PRED AVG SCORE: -0.5275, PRED PPL: 1.6947
# [2021-11-12 21:08:45,241 INFO] Translating shard 0.
# [2021-11-12 21:08:47,065 INFO] PRED AVG SCORE: -0.7130, PRED PPL: 2.0401
# [2021-11-12 21:08:47,443 INFO] Translating shard 0.
# [2021-11-12 21:08:49,493 INFO] PRED AVG SCORE: -0.5094, PRED PPL: 1.6644
# [2021-11-12 21:08:49,504 INFO] Translating shard 0.
# [2021-11-12 21:08:51,448 INFO] PRED AVG SCORE: -0.7115, PRED PPL: 2.0370
# [2021-11-12 21:08:51,802 INFO] Translating shard 0.
# [2021-11-12 21:08:53,535 INFO] PRED AVG SCORE: -0.5219, PRED PPL: 1.6852
# [2021-11-12 21:08:53,546 INFO] Translating shard 0.
# [2021-11-12 21:08:55,364 INFO] PRED AVG SCORE: -0.7181, PRED PPL: 2.0505
# [2021-11-12 21:08:55,793 INFO] Translating shard 0.
# [2021-11-12 21:08:57,798 INFO] PRED AVG SCORE: -0.4909, PRED PPL: 1.6337
# [2021-11-12 21:08:57,809 INFO] Translating shard 0.
# [2021-11-12 21:08:59,946 INFO] PRED AVG SCORE: -0.7007, PRED PPL: 2.0151
# [2021-11-12 21:09:00,307 INFO] Translating shard 0.
# [2021-11-12 21:09:02,647 INFO] PRED AVG SCORE: -0.5287, PRED PPL: 1.6968
# [2021-11-12 21:09:02,660 INFO] Translating shard 0.
# [2021-11-12 21:09:05,028 INFO] PRED AVG SCORE: -0.7197, PRED PPL: 2.0538
# [2021-11-12 21:09:05,432 INFO] Translating shard 0.
# [2021-11-12 21:09:07,304 INFO] PRED AVG SCORE: -0.5205, PRED PPL: 1.6829
# [2021-11-12 21:09:07,317 INFO] Translating shard 0.
# [2021-11-12 21:09:09,348 INFO] PRED AVG SCORE: -0.7175, PRED PPL: 2.0493
# [2021-11-12 21:09:09,749 INFO] Translating shard 0.
# [2021-11-12 21:09:11,508 INFO] PRED AVG SCORE: -0.5228, PRED PPL: 1.6868
# [2021-11-12 21:09:11,520 INFO] Translating shard 0.
# [2021-11-12 21:09:13,507 INFO] PRED AVG SCORE: -0.7256, PRED PPL: 2.0660
# [2021-11-12 21:09:13,891 INFO] Translating shard 0.
# [2021-11-12 21:09:15,830 INFO] PRED AVG SCORE: -0.5147, PRED PPL: 1.6732
# [2021-11-12 21:09:15,843 INFO] Translating shard 0.
# [2021-11-12 21:09:17,829 INFO] PRED AVG SCORE: -0.7083, PRED PPL: 2.0305
# [2021-11-12 21:09:18,204 INFO] Translating shard 0.
# [2021-11-12 21:09:19,993 INFO] PRED AVG SCORE: -0.5223, PRED PPL: 1.6860
# [2021-11-12 21:09:20,013 INFO] Translating shard 0.
# [2021-11-12 21:09:21,991 INFO] PRED AVG SCORE: -0.7180, PRED PPL: 2.0502
# [2021-11-12 21:09:22,366 INFO] Translating shard 0.
# [2021-11-12 21:09:24,183 INFO] PRED AVG SCORE: -0.5081, PRED PPL: 1.6622
# [2021-11-12 21:09:24,203 INFO] Translating shard 0.
# [2021-11-12 21:09:26,175 INFO] PRED AVG SCORE: -0.7254, PRED PPL: 2.0655
# [2021-11-12 21:09:26,546 INFO] Translating shard 0.
# [2021-11-12 21:09:28,254 INFO] PRED AVG SCORE: -0.5261, PRED PPL: 1.6923
# [2021-11-12 21:09:28,266 INFO] Translating shard 0.
# [2021-11-12 21:09:30,171 INFO] PRED AVG SCORE: -0.7154, PRED PPL: 2.0450
# [2021-11-12 21:09:30,593 INFO] Translating shard 0.
# [2021-11-12 21:09:33,496 INFO] PRED AVG SCORE: -0.5254, PRED PPL: 1.6911
# [2021-11-12 21:09:33,509 INFO] Translating shard 0.
# [2021-11-12 21:09:36,471 INFO] PRED AVG SCORE: -0.7216, PRED PPL: 2.0578
# [2021-11-12 21:09:36,841 INFO] Translating shard 0.
# [2021-11-12 21:09:38,627 INFO] PRED AVG SCORE: -0.5056, PRED PPL: 1.6579
# [2021-11-12 21:09:38,643 INFO] Translating shard 0.
# [2021-11-12 21:09:40,622 INFO] PRED AVG SCORE: -0.6990, PRED PPL: 2.0118
# [2021-11-12 21:09:40,998 INFO] Translating shard 0.
# [2021-11-12 21:09:42,901 INFO] PRED AVG SCORE: -0.5079, PRED PPL: 1.6618
# [2021-11-12 21:09:42,914 INFO] Translating shard 0.
# [2021-11-12 21:09:45,002 INFO] PRED AVG SCORE: -0.7094, PRED PPL: 2.0329
# [2021-11-12 21:09:45,445 INFO] Translating shard 0.
# [2021-11-12 21:09:47,508 INFO] PRED AVG SCORE: -0.5151, PRED PPL: 1.6738
# [2021-11-12 21:09:47,522 INFO] Translating shard 0.
# [2021-11-12 21:09:49,829 INFO] PRED AVG SCORE: -0.7089, PRED PPL: 2.0318
# [2021-11-12 21:09:50,234 INFO] Translating shard 0.
# [2021-11-12 21:09:52,248 INFO] PRED AVG SCORE: -0.5138, PRED PPL: 1.6716
# [2021-11-12 21:09:52,270 INFO] Translating shard 0.
# [2021-11-12 21:09:54,255 INFO] PRED AVG SCORE: -0.7131, PRED PPL: 2.0404
# [2021-11-12 21:09:54,673 INFO] Translating shard 0.
# [2021-11-12 21:09:56,526 INFO] PRED AVG SCORE: -0.5240, PRED PPL: 1.6888
# [2021-11-12 21:09:56,539 INFO] Translating shard 0.
# [2021-11-12 21:09:58,723 INFO] PRED AVG SCORE: -0.7188, PRED PPL: 2.0519
# [2021-11-12 21:09:59,126 INFO] Translating shard 0.
# [2021-11-12 21:10:01,087 INFO] PRED AVG SCORE: -0.5181, PRED PPL: 1.6789
# [2021-11-12 21:10:01,100 INFO] Translating shard 0.
# [2021-11-12 21:10:03,073 INFO] PRED AVG SCORE: -0.7127, PRED PPL: 2.0395
# [2021-11-12 21:10:03,411 INFO] Translating shard 0.
# [2021-11-12 21:10:05,275 INFO] PRED AVG SCORE: -0.5127, PRED PPL: 1.6697
# [2021-11-12 21:10:05,287 INFO] Translating shard 0.
# [2021-11-12 21:10:07,227 INFO] PRED AVG SCORE: -0.7046, PRED PPL: 2.0231
# [2021-11-12 21:10:07,572 INFO] Translating shard 0.
# [2021-11-12 21:10:09,338 INFO] PRED AVG SCORE: -0.5309, PRED PPL: 1.7005
# [2021-11-12 21:10:09,349 INFO] Translating shard 0.
# [2021-11-12 21:10:11,302 INFO] PRED AVG SCORE: -0.7282, PRED PPL: 2.0714
# [2021-11-12 21:10:11,667 INFO] Translating shard 0.
# [2021-11-12 21:10:13,530 INFO] PRED AVG SCORE: -0.4970, PRED PPL: 1.6437
# [2021-11-12 21:10:13,542 INFO] Translating shard 0.
# [2021-11-12 21:10:15,547 INFO] PRED AVG SCORE: -0.7131, PRED PPL: 2.0403
# [2021-11-12 21:10:15,932 INFO] Translating shard 0.
# [2021-11-12 21:10:17,879 INFO] PRED AVG SCORE: -0.5177, PRED PPL: 1.6781
# [2021-11-12 21:10:17,891 INFO] Translating shard 0.
# [2021-11-12 21:10:19,880 INFO] PRED AVG SCORE: -0.7327, PRED PPL: 2.0806
# [2021-11-12 21:10:20,239 INFO] Translating shard 0.
# [2021-11-12 21:10:22,139 INFO] PRED AVG SCORE: -0.5250, PRED PPL: 1.6904
# [2021-11-12 21:10:22,153 INFO] Translating shard 0.
# [2021-11-12 21:10:24,078 INFO] PRED AVG SCORE: -0.7193, PRED PPL: 2.0530
# [2021-11-12 21:10:24,436 INFO] Translating shard 0.
# [2021-11-12 21:10:26,174 INFO] PRED AVG SCORE: -0.5108, PRED PPL: 1.6666
# [2021-11-12 21:10:26,187 INFO] Translating shard 0.
# [2021-11-12 21:10:28,568 INFO] PRED AVG SCORE: -0.7197, PRED PPL: 2.0538
# [2021-11-12 21:10:28,926 INFO] Translating shard 0.
# [2021-11-12 21:10:30,756 INFO] PRED AVG SCORE: -0.5267, PRED PPL: 1.6934
# [2021-11-12 21:10:30,768 INFO] Translating shard 0.
# [2021-11-12 21:10:33,026 INFO] PRED AVG SCORE: -0.7325, PRED PPL: 2.0803
# [2021-11-12 21:10:33,383 INFO] Translating shard 0.
# [2021-11-12 21:10:35,174 INFO] PRED AVG SCORE: -0.5190, PRED PPL: 1.6803
# [2021-11-12 21:10:35,186 INFO] Translating shard 0.
# [2021-11-12 21:10:37,296 INFO] PRED AVG SCORE: -0.7209, PRED PPL: 2.0562
# [2021-11-12 21:10:37,653 INFO] Translating shard 0.
# [2021-11-12 21:10:39,798 INFO] PRED AVG SCORE: -0.5081, PRED PPL: 1.6621
# [2021-11-12 21:10:39,810 INFO] Translating shard 0.
# [2021-11-12 21:10:42,074 INFO] PRED AVG SCORE: -0.7102, PRED PPL: 2.0343
# [2021-11-12 21:10:42,456 INFO] Translating shard 0.
# [2021-11-12 21:10:44,296 INFO] PRED AVG SCORE: -0.5193, PRED PPL: 1.6808
# [2021-11-12 21:10:44,309 INFO] Translating shard 0.
# [2021-11-12 21:10:46,288 INFO] PRED AVG SCORE: -0.7283, PRED PPL: 2.0715
# [2021-11-12 21:10:46,625 INFO] Translating shard 0.
# [2021-11-12 21:10:48,515 INFO] PRED AVG SCORE: -0.5260, PRED PPL: 1.6922
# [2021-11-12 21:10:48,527 INFO] Translating shard 0.
# [2021-11-12 21:10:50,689 INFO] PRED AVG SCORE: -0.7192, PRED PPL: 2.0527
# [2021-11-12 21:10:51,098 INFO] Translating shard 0.
# [2021-11-12 21:10:53,146 INFO] PRED AVG SCORE: -0.5211, PRED PPL: 1.6839
# [2021-11-12 21:10:53,159 INFO] Translating shard 0.
# [2021-11-12 21:10:55,479 INFO] PRED AVG SCORE: -0.7251, PRED PPL: 2.0649
# [2021-11-12 21:10:55,838 INFO] Translating shard 0.
# [2021-11-12 21:10:57,693 INFO] PRED AVG SCORE: -0.5148, PRED PPL: 1.6733
# [2021-11-12 21:10:57,704 INFO] Translating shard 0.
# [2021-11-12 21:10:59,580 INFO] PRED AVG SCORE: -0.7122, PRED PPL: 2.0384
# [2021-11-12 21:10:59,937 INFO] Translating shard 0.
# [2021-11-12 21:11:01,697 INFO] PRED AVG SCORE: -0.5186, PRED PPL: 1.6797
# [2021-11-12 21:11:01,708 INFO] Translating shard 0.
# [2021-11-12 21:11:03,643 INFO] PRED AVG SCORE: -0.7235, PRED PPL: 2.0615
# [2021-11-12 21:11:04,057 INFO] Translating shard 0.
# [2021-11-12 21:11:05,866 INFO] PRED AVG SCORE: -0.5318, PRED PPL: 1.7021
# [2021-11-12 21:11:05,881 INFO] Translating shard 0.
# [2021-11-12 21:11:07,658 INFO] PRED AVG SCORE: -0.7056, PRED PPL: 2.0250
# [2021-11-12 21:11:08,013 INFO] Translating shard 0.
# [2021-11-12 21:11:09,744 INFO] PRED AVG SCORE: -0.5099, PRED PPL: 1.6652
# [2021-11-12 21:11:09,766 INFO] Translating shard 0.
# [2021-11-12 21:11:11,652 INFO] PRED AVG SCORE: -0.7162, PRED PPL: 2.0467
# [2021-11-12 21:11:12,073 INFO] Translating shard 0.
# [2021-11-12 21:11:13,817 INFO] PRED AVG SCORE: -0.5257, PRED PPL: 1.6916
# [2021-11-12 21:11:13,827 INFO] Translating shard 0.
# [2021-11-12 21:11:16,500 INFO] PRED AVG SCORE: -0.7334, PRED PPL: 2.0821
# [2021-11-12 21:11:16,859 INFO] Translating shard 0.
# [2021-11-12 21:11:18,638 INFO] PRED AVG SCORE: -0.5101, PRED PPL: 1.6655
# [2021-11-12 21:11:18,649 INFO] Translating shard 0.
# [2021-11-12 21:11:21,280 INFO] PRED AVG SCORE: -0.7133, PRED PPL: 2.0408
# [2021-11-12 21:11:21,663 INFO] Translating shard 0.
# [2021-11-12 21:11:23,568 INFO] PRED AVG SCORE: -0.5081, PRED PPL: 1.6622
# [2021-11-12 21:11:23,579 INFO] Translating shard 0.
# [2021-11-12 21:11:25,550 INFO] PRED AVG SCORE: -0.7165, PRED PPL: 2.0473
# [2021-11-12 21:11:25,869 INFO] Translating shard 0.
# [2021-11-12 21:11:27,620 INFO] PRED AVG SCORE: -0.5192, PRED PPL: 1.6807
# [2021-11-12 21:11:27,631 INFO] Translating shard 0.
# [2021-11-12 21:11:29,540 INFO] PRED AVG SCORE: -0.7057, PRED PPL: 2.0252
# [2021-11-12 21:11:29,884 INFO] Translating shard 0.
# [2021-11-12 21:11:31,612 INFO] PRED AVG SCORE: -0.5174, PRED PPL: 1.6777
# [2021-11-12 21:11:31,624 INFO] Translating shard 0.
# [2021-11-12 21:11:33,552 INFO] PRED AVG SCORE: -0.7145, PRED PPL: 2.0432
# [2021-11-12 21:11:33,875 INFO] Translating shard 0.
# [2021-11-12 21:11:35,612 INFO] PRED AVG SCORE: -0.5212, PRED PPL: 1.6841
# [2021-11-12 21:11:35,622 INFO] Translating shard 0.
# [2021-11-12 21:11:37,453 INFO] PRED AVG SCORE: -0.7234, PRED PPL: 2.0614
# [2021-11-12 21:11:37,790 INFO] Translating shard 0.
# [2021-11-12 21:11:39,776 INFO] PRED AVG SCORE: -0.5133, PRED PPL: 1.6708
# [2021-11-12 21:11:39,787 INFO] Translating shard 0.
# [2021-11-12 21:11:41,902 INFO] PRED AVG SCORE: -0.7105, PRED PPL: 2.0351
# [2021-11-12 21:11:42,257 INFO] Translating shard 0.
# [2021-11-12 21:11:44,040 INFO] PRED AVG SCORE: -0.5083, PRED PPL: 1.6624
# [2021-11-12 21:11:44,051 INFO] Translating shard 0.
# [2021-11-12 21:11:46,037 INFO] PRED AVG SCORE: -0.7075, PRED PPL: 2.0290
# [2021-11-12 21:11:46,360 INFO] Translating shard 0.
# [2021-11-12 21:11:48,577 INFO] PRED AVG SCORE: -0.5122, PRED PPL: 1.6690
# [2021-11-12 21:11:48,588 INFO] Translating shard 0.
# [2021-11-12 21:11:51,084 INFO] PRED AVG SCORE: -0.7287, PRED PPL: 2.0725
# [2021-11-12 21:11:51,431 INFO] Translating shard 0.
# [2021-11-12 21:11:53,334 INFO] PRED AVG SCORE: -0.5014, PRED PPL: 1.6510
# [2021-11-12 21:11:53,345 INFO] Translating shard 0.
# [2021-11-12 21:11:55,258 INFO] PRED AVG SCORE: -0.6951, PRED PPL: 2.0040
# [2021-11-12 21:11:55,618 INFO] Translating shard 0.
# [2021-11-12 21:11:57,319 INFO] PRED AVG SCORE: -0.5112, PRED PPL: 1.6672
# [2021-11-12 21:11:57,330 INFO] Translating shard 0.
# [2021-11-12 21:11:59,166 INFO] PRED AVG SCORE: -0.7116, PRED PPL: 2.0372
# [2021-11-12 21:11:59,488 INFO] Translating shard 0.
# [2021-11-12 21:12:01,356 INFO] PRED AVG SCORE: -0.5125, PRED PPL: 1.6695
# [2021-11-12 21:12:01,365 INFO] Translating shard 0.
# [2021-11-12 21:12:03,592 INFO] PRED AVG SCORE: -0.7130, PRED PPL: 2.0401
# [2021-11-12 21:12:03,935 INFO] Translating shard 0.
# [2021-11-12 21:12:05,752 INFO] PRED AVG SCORE: -0.5254, PRED PPL: 1.6911
# [2021-11-12 21:12:05,763 INFO] Translating shard 0.
# [2021-11-12 21:12:07,585 INFO] PRED AVG SCORE: -0.7145, PRED PPL: 2.0432
# [2021-11-12 21:12:07,906 INFO] Translating shard 0.
# [2021-11-12 21:12:09,665 INFO] PRED AVG SCORE: -0.5091, PRED PPL: 1.6638
# [2021-11-12 21:12:09,675 INFO] Translating shard 0.
# [2021-11-12 21:12:11,547 INFO] PRED AVG SCORE: -0.7176, PRED PPL: 2.0495
# [2021-11-12 21:12:11,890 INFO] Translating shard 0.
# [2021-11-12 21:12:13,673 INFO] PRED AVG SCORE: -0.5090, PRED PPL: 1.6636
# [2021-11-12 21:12:13,683 INFO] Translating shard 0.
# [2021-11-12 21:12:15,557 INFO] PRED AVG SCORE: -0.7179, PRED PPL: 2.0502
# [2021-11-12 21:12:15,878 INFO] Translating shard 0.
# [2021-11-12 21:12:17,498 INFO] PRED AVG SCORE: -0.5199, PRED PPL: 1.6818
# [2021-11-12 21:12:17,509 INFO] Translating shard 0.
# [2021-11-12 21:12:19,286 INFO] PRED AVG SCORE: -0.7166, PRED PPL: 2.0475
# [2021-11-12 21:12:19,613 INFO] Translating shard 0.
# [2021-11-12 21:12:21,330 INFO] PRED AVG SCORE: -0.5156, PRED PPL: 1.6747
# [2021-11-12 21:12:21,340 INFO] Translating shard 0.
# [2021-11-12 21:12:23,406 INFO] PRED AVG SCORE: -0.7229, PRED PPL: 2.0605
# [2021-11-12 21:12:23,745 INFO] Translating shard 0.
# [2021-11-12 21:12:25,761 INFO] PRED AVG SCORE: -0.5172, PRED PPL: 1.6773
# [2021-11-12 21:12:25,772 INFO] Translating shard 0.
# [2021-11-12 21:12:27,797 INFO] PRED AVG SCORE: -0.7136, PRED PPL: 2.0414
# [2021-11-12 21:12:28,135 INFO] Translating shard 0.
# [2021-11-12 21:12:29,861 INFO] PRED AVG SCORE: -0.5125, PRED PPL: 1.6695
# [2021-11-12 21:12:29,872 INFO] Translating shard 0.
# [2021-11-12 21:12:31,781 INFO] PRED AVG SCORE: -0.7070, PRED PPL: 2.0280
# [2021-11-12 21:12:32,141 INFO] Translating shard 0.
# [2021-11-12 21:12:34,085 INFO] PRED AVG SCORE: -0.5204, PRED PPL: 1.6827
# [2021-11-12 21:12:34,099 INFO] Translating shard 0.
# [2021-11-12 21:12:35,994 INFO] PRED AVG SCORE: -0.6993, PRED PPL: 2.0124
# [2021-11-12 21:12:36,360 INFO] Translating shard 0.
# [2021-11-12 21:12:38,135 INFO] PRED AVG SCORE: -0.5287, PRED PPL: 1.6968
# [2021-11-12 21:12:38,146 INFO] Translating shard 0.
# [2021-11-12 21:12:40,256 INFO] PRED AVG SCORE: -0.7193, PRED PPL: 2.0529
# [2021-11-12 21:12:40,693 INFO] Translating shard 0.
# [2021-11-12 21:12:42,926 INFO] PRED AVG SCORE: -0.5177, PRED PPL: 1.6781
# [2021-11-12 21:12:42,938 INFO] Translating shard 0.
# [2021-11-12 21:12:45,377 INFO] PRED AVG SCORE: -0.7145, PRED PPL: 2.0431
# [2021-11-12 21:12:45,782 INFO] Translating shard 0.
# [2021-11-12 21:12:47,658 INFO] PRED AVG SCORE: -0.5045, PRED PPL: 1.6562
# [2021-11-12 21:12:47,678 INFO] Translating shard 0.
# [2021-11-12 21:12:49,672 INFO] PRED AVG SCORE: -0.6960, PRED PPL: 2.0057
# [2021-11-12 21:12:50,105 INFO] Translating shard 0.
# [2021-11-12 21:12:51,877 INFO] PRED AVG SCORE: -0.5143, PRED PPL: 1.6725
# [2021-11-12 21:12:51,890 INFO] Translating shard 0.
# [2021-11-12 21:12:53,809 INFO] PRED AVG SCORE: -0.7198, PRED PPL: 2.0540
# [2021-11-12 21:12:54,175 INFO] Translating shard 0.
# [2021-11-12 21:12:56,301 INFO] PRED AVG SCORE: -0.5177, PRED PPL: 1.6781
# [2021-11-12 21:12:56,322 INFO] Translating shard 0.
# [2021-11-12 21:12:58,406 INFO] PRED AVG SCORE: -0.6998, PRED PPL: 2.0134
# [2021-11-12 21:12:58,812 INFO] Translating shard 0.
# [2021-11-12 21:13:00,765 INFO] PRED AVG SCORE: -0.5197, PRED PPL: 1.6815
# [2021-11-12 21:13:00,778 INFO] Translating shard 0.
# [2021-11-12 21:13:02,678 INFO] PRED AVG SCORE: -0.7147, PRED PPL: 2.0436
# [2021-11-12 21:13:03,059 INFO] Translating shard 0.
# [2021-11-12 21:13:04,836 INFO] PRED AVG SCORE: -0.5165, PRED PPL: 1.6761
# [2021-11-12 21:13:04,848 INFO] Translating shard 0.
# [2021-11-12 21:13:06,736 INFO] PRED AVG SCORE: -0.7137, PRED PPL: 2.0416
# [2021-11-12 21:13:07,105 INFO] Translating shard 0.
# [2021-11-12 21:13:08,950 INFO] PRED AVG SCORE: -0.5113, PRED PPL: 1.6674
# [2021-11-12 21:13:08,963 INFO] Translating shard 0.
# [2021-11-12 21:13:10,765 INFO] PRED AVG SCORE: -0.7304, PRED PPL: 2.0759
# [2021-11-12 21:13:11,150 INFO] Translating shard 0.
# [2021-11-12 21:13:12,968 INFO] PRED AVG SCORE: -0.5121, PRED PPL: 1.6688
# [2021-11-12 21:13:12,980 INFO] Translating shard 0.
# [2021-11-12 21:13:15,114 INFO] PRED AVG SCORE: -0.7238, PRED PPL: 2.0623
# [2021-11-12 21:13:15,506 INFO] Translating shard 0.
# [2021-11-12 21:13:17,392 INFO] PRED AVG SCORE: -0.5222, PRED PPL: 1.6857
# [2021-11-12 21:13:17,405 INFO] Translating shard 0.
# [2021-11-12 21:13:19,410 INFO] PRED AVG SCORE: -0.7170, PRED PPL: 2.0482
# [2021-11-12 21:13:19,800 INFO] Translating shard 0.
# [2021-11-12 21:13:21,698 INFO] PRED AVG SCORE: -0.5065, PRED PPL: 1.6594
# [2021-11-12 21:13:21,720 INFO] Translating shard 0.
# [2021-11-12 21:13:23,657 INFO] PRED AVG SCORE: -0.7084, PRED PPL: 2.0307
# [2021-11-12 21:13:24,028 INFO] Translating shard 0.
# [2021-11-12 21:13:26,169 INFO] PRED AVG SCORE: -0.5064, PRED PPL: 1.6593
# [2021-11-12 21:13:26,182 INFO] Translating shard 0.
# [2021-11-12 21:13:28,192 INFO] PRED AVG SCORE: -0.7028, PRED PPL: 2.0194
# [2021-11-12 21:13:28,586 INFO] Translating shard 0.
# [2021-11-12 21:13:30,363 INFO] PRED AVG SCORE: -0.5392, PRED PPL: 1.7146
# [2021-11-12 21:13:30,383 INFO] Translating shard 0.
# [2021-11-12 21:13:32,790 INFO] PRED AVG SCORE: -0.7362, PRED PPL: 2.0879
# [2021-11-12 21:13:33,184 INFO] Translating shard 0.
# [2021-11-12 21:13:35,019 INFO] PRED AVG SCORE: -0.5082, PRED PPL: 1.6623
# [2021-11-12 21:13:35,032 INFO] Translating shard 0.
# [2021-11-12 21:13:37,534 INFO] PRED AVG SCORE: -0.7051, PRED PPL: 2.0240
# [2021-11-12 21:13:37,906 INFO] Translating shard 0.
# [2021-11-12 21:13:40,011 INFO] PRED AVG SCORE: -0.5071, PRED PPL: 1.6605
# [2021-11-12 21:13:40,024 INFO] Translating shard 0.
# [2021-11-12 21:13:42,329 INFO] PRED AVG SCORE: -0.6988, PRED PPL: 2.0114
# [2021-11-12 21:13:42,760 INFO] Translating shard 0.
# [2021-11-12 21:13:44,802 INFO] PRED AVG SCORE: -0.5035, PRED PPL: 1.6546
# [2021-11-12 21:13:44,815 INFO] Translating shard 0.
# [2021-11-12 21:13:46,864 INFO] PRED AVG SCORE: -0.7025, PRED PPL: 2.0187
# [2021-11-12 21:13:47,281 INFO] Translating shard 0.
# [2021-11-12 21:13:49,148 INFO] PRED AVG SCORE: -0.5152, PRED PPL: 1.6740
# [2021-11-12 21:13:49,161 INFO] Translating shard 0.
# [2021-11-12 21:13:51,095 INFO] PRED AVG SCORE: -0.7204, PRED PPL: 2.0553
# [2021-11-12 21:13:51,465 INFO] Translating shard 0.
# [2021-11-12 21:13:53,300 INFO] PRED AVG SCORE: -0.5174, PRED PPL: 1.6777
# [2021-11-12 21:13:53,313 INFO] Translating shard 0.
# [2021-11-12 21:13:55,788 INFO] PRED AVG SCORE: -0.7008, PRED PPL: 2.0153
# [2021-11-12 21:13:56,193 INFO] Translating shard 0.
# [2021-11-12 21:13:58,014 INFO] PRED AVG SCORE: -0.5207, PRED PPL: 1.6832
# [2021-11-12 21:13:58,027 INFO] Translating shard 0.
# [2021-11-12 21:14:00,509 INFO] PRED AVG SCORE: -0.7334, PRED PPL: 2.0822
# [2021-11-12 21:14:00,895 INFO] Translating shard 0.
# [2021-11-12 21:14:02,697 INFO] PRED AVG SCORE: -0.5255, PRED PPL: 1.6912
# [2021-11-12 21:14:02,718 INFO] Translating shard 0.
# [2021-11-12 21:14:04,848 INFO] PRED AVG SCORE: -0.7273, PRED PPL: 2.0695
# [2021-11-12 21:14:05,233 INFO] Translating shard 0.
# [2021-11-12 21:14:07,098 INFO] PRED AVG SCORE: -0.4978, PRED PPL: 1.6451
# [2021-11-12 21:14:07,111 INFO] Translating shard 0.
# [2021-11-12 21:14:08,955 INFO] PRED AVG SCORE: -0.6962, PRED PPL: 2.0060
# [2021-11-12 21:14:09,313 INFO] Translating shard 0.
# [2021-11-12 21:14:11,183 INFO] PRED AVG SCORE: -0.5091, PRED PPL: 1.6638
# [2021-11-12 21:14:11,196 INFO] Translating shard 0.
# [2021-11-12 21:14:13,553 INFO] PRED AVG SCORE: -0.7119, PRED PPL: 2.0379
# [2021-11-12 21:14:13,936 INFO] Translating shard 0.
# [2021-11-12 21:14:15,845 INFO] PRED AVG SCORE: -0.5081, PRED PPL: 1.6621
# [2021-11-12 21:14:15,858 INFO] Translating shard 0.
# [2021-11-12 21:14:17,779 INFO] PRED AVG SCORE: -0.7087, PRED PPL: 2.0314
# [2021-11-12 21:14:18,170 INFO] Translating shard 0.
# [2021-11-12 21:14:19,979 INFO] PRED AVG SCORE: -0.5133, PRED PPL: 1.6708
# [2021-11-12 21:14:19,993 INFO] Translating shard 0.
# [2021-11-12 21:14:21,987 INFO] PRED AVG SCORE: -0.7111, PRED PPL: 2.0362
# [2021-11-12 21:14:22,378 INFO] Translating shard 0.
# [2021-11-12 21:14:24,313 INFO] PRED AVG SCORE: -0.5206, PRED PPL: 1.6830
# [2021-11-12 21:14:24,334 INFO] Translating shard 0.
# [2021-11-12 21:14:26,742 INFO] PRED AVG SCORE: -0.7265, PRED PPL: 2.0678
# [2021-11-12 21:14:27,123 INFO] Translating shard 0.
# [2021-11-12 21:14:28,996 INFO] PRED AVG SCORE: -0.5100, PRED PPL: 1.6652
# [2021-11-12 21:14:29,009 INFO] Translating shard 0.
# [2021-11-12 21:14:30,995 INFO] PRED AVG SCORE: -0.6986, PRED PPL: 2.0109
# [2021-11-12 21:14:31,364 INFO] Translating shard 0.
# [2021-11-12 21:14:33,553 INFO] PRED AVG SCORE: -0.5060, PRED PPL: 1.6586
# [2021-11-12 21:14:33,574 INFO] Translating shard 0.
# [2021-11-12 21:14:35,872 INFO] PRED AVG SCORE: -0.7026, PRED PPL: 2.0191
# [2021-11-12 21:14:36,278 INFO] Translating shard 0.
# [2021-11-12 21:14:38,153 INFO] PRED AVG SCORE: -0.5262, PRED PPL: 1.6925
# [2021-11-12 21:14:38,166 INFO] Translating shard 0.
# [2021-11-12 21:14:40,078 INFO] PRED AVG SCORE: -0.7190, PRED PPL: 2.0524
# [2021-11-12 21:14:40,483 INFO] Translating shard 0.
# [2021-11-12 21:14:42,300 INFO] PRED AVG SCORE: -0.5160, PRED PPL: 1.6753
# [2021-11-12 21:14:42,312 INFO] Translating shard 0.
# [2021-11-12 21:14:44,271 INFO] PRED AVG SCORE: -0.7095, PRED PPL: 2.0330
# [2021-11-12 21:14:44,649 INFO] Translating shard 0.
# [2021-11-12 21:14:46,610 INFO] PRED AVG SCORE: -0.5160, PRED PPL: 1.6754
# [2021-11-12 21:14:46,625 INFO] Translating shard 0.
# [2021-11-12 21:14:48,914 INFO] PRED AVG SCORE: -0.6951, PRED PPL: 2.0038
# [2021-11-12 21:14:49,304 INFO] Translating shard 0.
# [2021-11-12 21:14:51,038 INFO] PRED AVG SCORE: -0.5172, PRED PPL: 1.6773
# [2021-11-12 21:14:51,059 INFO] Translating shard 0.
# [2021-11-12 21:14:52,892 INFO] PRED AVG SCORE: -0.7133, PRED PPL: 2.0407
# [2021-11-12 21:14:53,254 INFO] Translating shard 0.
# [2021-11-12 21:14:55,270 INFO] PRED AVG SCORE: -0.5294, PRED PPL: 1.6980
# [2021-11-12 21:14:55,283 INFO] Translating shard 0.
# [2021-11-12 21:14:57,457 INFO] PRED AVG SCORE: -0.7088, PRED PPL: 2.0316
# [2021-11-12 21:14:57,835 INFO] Translating shard 0.
# [2021-11-12 21:14:59,663 INFO] PRED AVG SCORE: -0.5147, PRED PPL: 1.6732
# [2021-11-12 21:14:59,675 INFO] Translating shard 0.
# [2021-11-12 21:15:01,595 INFO] PRED AVG SCORE: -0.7149, PRED PPL: 2.0440
# [2021-11-12 21:15:01,999 INFO] Translating shard 0.
# [2021-11-12 21:15:04,177 INFO] PRED AVG SCORE: -0.5151, PRED PPL: 1.6739
# [2021-11-12 21:15:04,189 INFO] Translating shard 0.
# [2021-11-12 21:15:06,746 INFO] PRED AVG SCORE: -0.7072, PRED PPL: 2.0283
# [2021-11-12 21:15:07,152 INFO] Translating shard 0.
# [2021-11-12 21:15:08,920 INFO] PRED AVG SCORE: -0.5152, PRED PPL: 1.6739
# [2021-11-12 21:15:08,932 INFO] Translating shard 0.
# [2021-11-12 21:15:10,964 INFO] PRED AVG SCORE: -0.7095, PRED PPL: 2.0329
# [2021-11-12 21:15:11,348 INFO] Translating shard 0.
# [2021-11-12 21:15:13,072 INFO] PRED AVG SCORE: -0.5146, PRED PPL: 1.6730
# [2021-11-12 21:15:13,085 INFO] Translating shard 0.
# [2021-11-12 21:15:15,021 INFO] PRED AVG SCORE: -0.7083, PRED PPL: 2.0305
# [2021-11-12 21:15:15,386 INFO] Translating shard 0.
# [2021-11-12 21:15:17,238 INFO] PRED AVG SCORE: -0.5183, PRED PPL: 1.6792
# [2021-11-12 21:15:17,251 INFO] Translating shard 0.
# [2021-11-12 21:15:19,108 INFO] PRED AVG SCORE: -0.7160, PRED PPL: 2.0463
# [2021-11-12 21:15:19,488 INFO] Translating shard 0.
# [2021-11-12 21:15:21,475 INFO] PRED AVG SCORE: -0.5205, PRED PPL: 1.6828
# [2021-11-12 21:15:21,497 INFO] Translating shard 0.
# [2021-11-12 21:15:23,527 INFO] PRED AVG SCORE: -0.7249, PRED PPL: 2.0645
# [2021-11-12 21:15:23,902 INFO] Translating shard 0.
# [2021-11-12 21:15:25,718 INFO] PRED AVG SCORE: -0.5013, PRED PPL: 1.6508
# [2021-11-12 21:15:25,736 INFO] Translating shard 0.
# [2021-11-12 21:15:27,811 INFO] PRED AVG SCORE: -0.7166, PRED PPL: 2.0474
# [2021-11-12 21:15:28,150 INFO] Translating shard 0.
# [2021-11-12 21:15:30,053 INFO] PRED AVG SCORE: -0.5051, PRED PPL: 1.6571
# [2021-11-12 21:15:30,067 INFO] Translating shard 0.
# [2021-11-12 21:15:32,168 INFO] PRED AVG SCORE: -0.7150, PRED PPL: 2.0443
# [2021-11-12 21:15:32,553 INFO] Translating shard 0.
# [2021-11-12 21:15:34,309 INFO] PRED AVG SCORE: -0.5025, PRED PPL: 1.6529
# [2021-11-12 21:15:34,322 INFO] Translating shard 0.
# [2021-11-12 21:15:36,310 INFO] PRED AVG SCORE: -0.7062, PRED PPL: 2.0263
# [2021-11-12 21:15:36,662 INFO] Translating shard 0.
# [2021-11-12 21:15:38,496 INFO] PRED AVG SCORE: -0.5145, PRED PPL: 1.6728
# [2021-11-12 21:15:38,508 INFO] Translating shard 0.
# [2021-11-12 21:15:40,573 INFO] PRED AVG SCORE: -0.7010, PRED PPL: 2.0157
# [2021-11-12 21:15:40,959 INFO] Translating shard 0.
# [2021-11-12 21:15:42,901 INFO] PRED AVG SCORE: -0.5214, PRED PPL: 1.6844
# [2021-11-12 21:15:42,914 INFO] Translating shard 0.
# [2021-11-12 21:15:45,083 INFO] PRED AVG SCORE: -0.7236, PRED PPL: 2.0619
# [2021-11-12 21:15:45,463 INFO] Translating shard 0.
# [2021-11-12 21:15:47,122 INFO] PRED AVG SCORE: -0.5156, PRED PPL: 1.6746
# [2021-11-12 21:15:47,133 INFO] Translating shard 0.
# [2021-11-12 21:15:48,917 INFO] PRED AVG SCORE: -0.7216, PRED PPL: 2.0578
# [2021-11-12 21:15:49,280 INFO] Translating shard 0.
# [2021-11-12 21:15:51,118 INFO] PRED AVG SCORE: -0.5030, PRED PPL: 1.6537
# [2021-11-12 21:15:51,131 INFO] Translating shard 0.
# [2021-11-12 21:15:53,236 INFO] PRED AVG SCORE: -0.7158, PRED PPL: 2.0458
# [2021-11-12 21:15:53,560 INFO] Translating shard 0.
# [2021-11-12 21:15:55,338 INFO] PRED AVG SCORE: -0.5136, PRED PPL: 1.6712
# [2021-11-12 21:15:55,350 INFO] Translating shard 0.
# [2021-11-12 21:15:57,169 INFO] PRED AVG SCORE: -0.7266, PRED PPL: 2.0679
# [2021-11-12 21:15:57,528 INFO] Translating shard 0.
# [2021-11-12 21:15:59,515 INFO] PRED AVG SCORE: -0.5066, PRED PPL: 1.6597
# [2021-11-12 21:15:59,527 INFO] Translating shard 0.
# [2021-11-12 21:16:01,826 INFO] PRED AVG SCORE: -0.7209, PRED PPL: 2.0563
# [2021-11-12 21:16:02,177 INFO] Translating shard 0.
# [2021-11-12 21:16:04,286 INFO] PRED AVG SCORE: -0.5166, PRED PPL: 1.6763
# [2021-11-12 21:16:04,303 INFO] Translating shard 0.
# [2021-11-12 21:16:06,404 INFO] PRED AVG SCORE: -0.7190, PRED PPL: 2.0523
# [2021-11-12 21:16:06,752 INFO] Translating shard 0.
# [2021-11-12 21:16:08,687 INFO] PRED AVG SCORE: -0.5252, PRED PPL: 1.6909
# [2021-11-12 21:16:08,701 INFO] Translating shard 0.
# [2021-11-12 21:16:10,755 INFO] PRED AVG SCORE: -0.7210, PRED PPL: 2.0565
# [2021-11-12 21:16:11,190 INFO] Translating shard 0.
# [2021-11-12 21:16:13,008 INFO] PRED AVG SCORE: -0.5196, PRED PPL: 1.6814
# [2021-11-12 21:16:13,020 INFO] Translating shard 0.
# [2021-11-12 21:16:14,839 INFO] PRED AVG SCORE: -0.7128, PRED PPL: 2.0396
# [2021-11-12 21:16:15,231 INFO] Translating shard 0.
# [2021-11-12 21:16:17,002 INFO] PRED AVG SCORE: -0.5051, PRED PPL: 1.6572
# [2021-11-12 21:16:17,015 INFO] Translating shard 0.
# [2021-11-12 21:16:19,136 INFO] PRED AVG SCORE: -0.7133, PRED PPL: 2.0408
# [2021-11-12 21:16:19,559 INFO] Translating shard 0.
# [2021-11-12 21:16:21,664 INFO] PRED AVG SCORE: -0.5081, PRED PPL: 1.6621
# [2021-11-12 21:16:21,679 INFO] Translating shard 0.
# [2021-11-12 21:16:23,778 INFO] PRED AVG SCORE: -0.7121, PRED PPL: 2.0384
# [2021-11-12 21:16:24,207 INFO] Translating shard 0.
# [2021-11-12 21:16:25,963 INFO] PRED AVG SCORE: -0.5310, PRED PPL: 1.7006
# [2021-11-12 21:16:25,974 INFO] Translating shard 0.
# [2021-11-12 21:16:27,773 INFO] PRED AVG SCORE: -0.7071, PRED PPL: 2.0282
# [2021-11-12 21:16:28,148 INFO] Translating shard 0.
# [2021-11-12 21:16:29,896 INFO] PRED AVG SCORE: -0.5249, PRED PPL: 1.6903
# [2021-11-12 21:16:29,906 INFO] Translating shard 0.
# [2021-11-12 21:16:31,730 INFO] PRED AVG SCORE: -0.7221, PRED PPL: 2.0587
# [2021-11-12 21:16:32,085 INFO] Translating shard 0.
# [2021-11-12 21:16:34,981 INFO] PRED AVG SCORE: -0.5249, PRED PPL: 1.6903
# [2021-11-12 21:16:34,994 INFO] Translating shard 0.
# [2021-11-12 21:16:37,985 INFO] PRED AVG SCORE: -0.7132, PRED PPL: 2.0406
# [2021-11-12 21:16:38,384 INFO] Translating shard 0.
# [2021-11-12 21:16:40,314 INFO] PRED AVG SCORE: -0.5056, PRED PPL: 1.6579
# [2021-11-12 21:16:40,328 INFO] Translating shard 0.
# [2021-11-12 21:16:42,365 INFO] PRED AVG SCORE: -0.6831, PRED PPL: 1.9800
# [2021-11-12 21:16:42,749 INFO] Translating shard 0.
# [2021-11-12 21:16:49,243 INFO] PRED AVG SCORE: -0.5160, PRED PPL: 1.6753
# [2021-11-12 21:16:49,256 INFO] Translating shard 0.
# [2021-11-12 21:16:51,351 INFO] PRED AVG SCORE: -0.7212, PRED PPL: 2.0568
# [2021-11-12 21:16:51,713 INFO] Translating shard 0.
# [2021-11-12 21:16:53,634 INFO] PRED AVG SCORE: -0.5139, PRED PPL: 1.6718
# [2021-11-12 21:16:53,646 INFO] Translating shard 0.
# [2021-11-12 21:16:55,588 INFO] PRED AVG SCORE: -0.7133, PRED PPL: 2.0406
# [2021-11-12 21:16:55,951 INFO] Translating shard 0.
# [2021-11-12 21:16:57,614 INFO] PRED AVG SCORE: -0.5312, PRED PPL: 1.7009
# [2021-11-12 21:16:57,625 INFO] Translating shard 0.
# [2021-11-12 21:16:59,401 INFO] PRED AVG SCORE: -0.7239, PRED PPL: 2.0624
# [2021-11-12 21:16:59,786 INFO] Translating shard 0.
# [2021-11-12 21:17:01,563 INFO] PRED AVG SCORE: -0.5127, PRED PPL: 1.6697
# [2021-11-12 21:17:01,576 INFO] Translating shard 0.
# [2021-11-12 21:17:03,543 INFO] PRED AVG SCORE: -0.7023, PRED PPL: 2.0184
# [2021-11-12 21:17:03,926 INFO] Translating shard 0.
# [2021-11-12 21:17:05,791 INFO] PRED AVG SCORE: -0.5151, PRED PPL: 1.6738
# [2021-11-12 21:17:05,803 INFO] Translating shard 0.
# [2021-11-12 21:17:07,840 INFO] PRED AVG SCORE: -0.7122, PRED PPL: 2.0384
# [2021-11-12 21:17:08,207 INFO] Translating shard 0.
# [2021-11-12 21:17:10,029 INFO] PRED AVG SCORE: -0.5126, PRED PPL: 1.6697
# [2021-11-12 21:17:10,050 INFO] Translating shard 0.
# [2021-11-12 21:17:12,225 INFO] PRED AVG SCORE: -0.7083, PRED PPL: 2.0306
# [2021-11-12 21:17:12,608 INFO] Translating shard 0.
# [2021-11-12 21:17:14,315 INFO] PRED AVG SCORE: -0.5227, PRED PPL: 1.6866
# [2021-11-12 21:17:14,327 INFO] Translating shard 0.
# [2021-11-12 21:17:16,648 INFO] PRED AVG SCORE: -0.7214, PRED PPL: 2.0573
# [2021-11-12 21:17:17,054 INFO] Translating shard 0.
# [2021-11-12 21:17:18,905 INFO] PRED AVG SCORE: -0.5234, PRED PPL: 1.6877
# [2021-11-12 21:17:18,920 INFO] Translating shard 0.
# [2021-11-12 21:17:21,272 INFO] PRED AVG SCORE: -0.7207, PRED PPL: 2.0558
# [2021-11-12 21:17:21,697 INFO] Translating shard 0.
# [2021-11-12 21:17:23,458 INFO] PRED AVG SCORE: -0.5170, PRED PPL: 1.6769
# [2021-11-12 21:17:23,472 INFO] Translating shard 0.
# [2021-11-12 21:17:25,366 INFO] PRED AVG SCORE: -0.7087, PRED PPL: 2.0313
# [2021-11-12 21:17:25,758 INFO] Translating shard 0.
# [2021-11-12 21:17:27,561 INFO] PRED AVG SCORE: -0.5358, PRED PPL: 1.7088
# [2021-11-12 21:17:27,573 INFO] Translating shard 0.
# [2021-11-12 21:17:29,543 INFO] PRED AVG SCORE: -0.7136, PRED PPL: 2.0413
# [2021-11-12 21:17:29,932 INFO] Translating shard 0.
# [2021-11-12 21:17:32,080 INFO] PRED AVG SCORE: -0.5210, PRED PPL: 1.6837
# [2021-11-12 21:17:32,101 INFO] Translating shard 0.
# [2021-11-12 21:17:34,146 INFO] PRED AVG SCORE: -0.7097, PRED PPL: 2.0333
# [2021-11-12 21:17:34,538 INFO] Translating shard 0.
# [2021-11-12 21:17:36,559 INFO] PRED AVG SCORE: -0.5212, PRED PPL: 1.6840
# [2021-11-12 21:17:36,579 INFO] Translating shard 0.
# [2021-11-12 21:17:38,662 INFO] PRED AVG SCORE: -0.7155, PRED PPL: 2.0452
# [2021-11-12 21:17:39,043 INFO] Translating shard 0.
# [2021-11-12 21:17:40,856 INFO] PRED AVG SCORE: -0.5169, PRED PPL: 1.6769
# [2021-11-12 21:17:40,868 INFO] Translating shard 0.
# [2021-11-12 21:17:43,232 INFO] PRED AVG SCORE: -0.7237, PRED PPL: 2.0620
# [2021-11-12 21:17:43,670 INFO] Translating shard 0.
# [2021-11-12 21:17:45,518 INFO] PRED AVG SCORE: -0.5117, PRED PPL: 1.6682
# [2021-11-12 21:17:45,531 INFO] Translating shard 0.
# [2021-11-12 21:17:47,660 INFO] PRED AVG SCORE: -0.7224, PRED PPL: 2.0594
# [2021-11-12 21:17:48,047 INFO] Translating shard 0.
# [2021-11-12 21:17:50,239 INFO] PRED AVG SCORE: -0.5220, PRED PPL: 1.6854
# [2021-11-12 21:17:50,253 INFO] Translating shard 0.
# [2021-11-12 21:17:52,502 INFO] PRED AVG SCORE: -0.7146, PRED PPL: 2.0434
# [2021-11-12 21:17:52,906 INFO] Translating shard 0.
# [2021-11-12 21:17:54,687 INFO] PRED AVG SCORE: -0.5328, PRED PPL: 1.7038
# [2021-11-12 21:17:54,700 INFO] Translating shard 0.
# [2021-11-12 21:17:57,078 INFO] PRED AVG SCORE: -0.7329, PRED PPL: 2.0811
# [2021-11-12 21:17:57,466 INFO] Translating shard 0.
# [2021-11-12 21:17:59,217 INFO] PRED AVG SCORE: -0.5290, PRED PPL: 1.6973
# [2021-11-12 21:17:59,230 INFO] Translating shard 0.
# [2021-11-12 21:18:01,579 INFO] PRED AVG SCORE: -0.7270, PRED PPL: 2.0689
# [2021-11-12 21:18:01,958 INFO] Translating shard 0.
# [2021-11-12 21:18:03,847 INFO] PRED AVG SCORE: -0.5041, PRED PPL: 1.6554
# [2021-11-12 21:18:03,876 INFO] Translating shard 0.
# [2021-11-12 21:18:05,920 INFO] PRED AVG SCORE: -0.7080, PRED PPL: 2.0300
# [2021-11-12 21:18:06,314 INFO] Translating shard 0.
# [2021-11-12 21:18:08,447 INFO] PRED AVG SCORE: -0.5026, PRED PPL: 1.6530
# [2021-11-12 21:18:08,459 INFO] Translating shard 0.
# [2021-11-12 21:18:10,764 INFO] PRED AVG SCORE: -0.6986, PRED PPL: 2.0109
# [2021-11-12 21:18:11,155 INFO] Translating shard 0.
# [2021-11-12 21:18:12,895 INFO] PRED AVG SCORE: -0.5211, PRED PPL: 1.6839
# [2021-11-12 21:18:12,915 INFO] Translating shard 0.
# [2021-11-12 21:18:15,322 INFO] PRED AVG SCORE: -0.7251, PRED PPL: 2.0649
# [2021-11-12 21:18:15,730 INFO] Translating shard 0.
# [2021-11-12 21:18:17,460 INFO] PRED AVG SCORE: -0.5124, PRED PPL: 1.6692
# [2021-11-12 21:18:17,473 INFO] Translating shard 0.
# [2021-11-12 21:18:19,491 INFO] PRED AVG SCORE: -0.7204, PRED PPL: 2.0553
# [2021-11-12 21:18:19,861 INFO] Translating shard 0.
# [2021-11-12 21:18:21,652 INFO] PRED AVG SCORE: -0.4926, PRED PPL: 1.6365
# [2021-11-12 21:18:21,674 INFO] Translating shard 0.
# [2021-11-12 21:18:23,544 INFO] PRED AVG SCORE: -0.7068, PRED PPL: 2.0274
# [2021-11-12 21:18:23,924 INFO] Translating shard 0.
# [2021-11-12 21:18:26,212 INFO] PRED AVG SCORE: -0.5195, PRED PPL: 1.6812
# [2021-11-12 21:18:26,226 INFO] Translating shard 0.
# [2021-11-12 21:18:28,128 INFO] PRED AVG SCORE: -0.7125, PRED PPL: 2.0390
# [2021-11-12 21:18:28,508 INFO] Translating shard 0.
# [2021-11-12 21:18:30,357 INFO] PRED AVG SCORE: -0.5211, PRED PPL: 1.6839
# [2021-11-12 21:18:30,370 INFO] Translating shard 0.
# [2021-11-12 21:18:32,365 INFO] PRED AVG SCORE: -0.7120, PRED PPL: 2.0380
# [2021-11-12 21:18:32,721 INFO] Translating shard 0.
# [2021-11-12 21:18:34,584 INFO] PRED AVG SCORE: -0.5224, PRED PPL: 1.6860
# [2021-11-12 21:18:34,597 INFO] Translating shard 0.
# [2021-11-12 21:18:36,612 INFO] PRED AVG SCORE: -0.7185, PRED PPL: 2.0514
# [2021-11-12 21:18:37,043 INFO] Translating shard 0.
# [2021-11-12 21:18:38,906 INFO] PRED AVG SCORE: -0.5195, PRED PPL: 1.6812
# [2021-11-12 21:18:38,921 INFO] Translating shard 0.
# [2021-11-12 21:18:40,986 INFO] PRED AVG SCORE: -0.7213, PRED PPL: 2.0571
# [2021-11-12 21:18:41,407 INFO] Translating shard 0.
# [2021-11-12 21:18:43,340 INFO] PRED AVG SCORE: -0.5185, PRED PPL: 1.6795
# [2021-11-12 21:18:43,361 INFO] Translating shard 0.
# [2021-11-12 21:18:45,215 INFO] PRED AVG SCORE: -0.7103, PRED PPL: 2.0346
# [2021-11-12 21:18:45,555 INFO] Translating shard 0.
# [2021-11-12 21:18:47,717 INFO] PRED AVG SCORE: -0.5227, PRED PPL: 1.6866
# [2021-11-12 21:18:47,728 INFO] Translating shard 0.
# [2021-11-12 21:18:49,981 INFO] PRED AVG SCORE: -0.7140, PRED PPL: 2.0421
# [2021-11-12 21:18:50,398 INFO] Translating shard 0.
# [2021-11-12 21:18:52,255 INFO] PRED AVG SCORE: -0.5106, PRED PPL: 1.6663
# [2021-11-12 21:18:52,269 INFO] Translating shard 0.
# [2021-11-12 21:18:54,273 INFO] PRED AVG SCORE: -0.7075, PRED PPL: 2.0288
# [2021-11-12 21:18:54,646 INFO] Translating shard 0.
# [2021-11-12 21:18:56,209 INFO] PRED AVG SCORE: -0.5132, PRED PPL: 1.6706
# [2021-11-12 21:18:56,219 INFO] Translating shard 0.
# [2021-11-12 21:18:57,994 INFO] PRED AVG SCORE: -0.7205, PRED PPL: 2.0555
# [2021-11-12 21:18:58,330 INFO] Translating shard 0.
# [2021-11-12 21:19:00,087 INFO] PRED AVG SCORE: -0.5254, PRED PPL: 1.6911
# [2021-11-12 21:19:00,100 INFO] Translating shard 0.
# [2021-11-12 21:19:01,999 INFO] PRED AVG SCORE: -0.7252, PRED PPL: 2.0652
# [2021-11-12 21:19:02,345 INFO] Translating shard 0.
# [2021-11-12 21:19:04,500 INFO] PRED AVG SCORE: -0.5144, PRED PPL: 1.6726
# [2021-11-12 21:19:04,515 INFO] Translating shard 0.
# [2021-11-12 21:19:07,330 INFO] PRED AVG SCORE: -0.7041, PRED PPL: 2.0220
# [2021-11-12 21:19:07,708 INFO] Translating shard 0.
# [2021-11-12 21:19:09,734 INFO] PRED AVG SCORE: -0.5232, PRED PPL: 1.6874
# [2021-11-12 21:19:09,745 INFO] Translating shard 0.
# [2021-11-12 21:19:11,948 INFO] PRED AVG SCORE: -0.7163, PRED PPL: 2.0468
# [2021-11-12 21:19:12,304 INFO] Translating shard 0.
# [2021-11-12 21:19:14,149 INFO] PRED AVG SCORE: -0.5076, PRED PPL: 1.6613
# [2021-11-12 21:19:14,169 INFO] Translating shard 0.
# [2021-11-12 21:19:16,126 INFO] PRED AVG SCORE: -0.7025, PRED PPL: 2.0188
# [2021-11-12 21:19:16,493 INFO] Translating shard 0.
# [2021-11-12 21:19:18,359 INFO] PRED AVG SCORE: -0.5153, PRED PPL: 1.6741
# [2021-11-12 21:19:18,372 INFO] Translating shard 0.
# [2021-11-12 21:19:20,258 INFO] PRED AVG SCORE: -0.7208, PRED PPL: 2.0561
# [2021-11-12 21:19:20,653 INFO] Translating shard 0.
# [2021-11-12 21:19:22,432 INFO] PRED AVG SCORE: -0.5245, PRED PPL: 1.6896
# [2021-11-12 21:19:22,453 INFO] Translating shard 0.
# [2021-11-12 21:19:24,563 INFO] PRED AVG SCORE: -0.7206, PRED PPL: 2.0557
# [2021-11-12 21:19:24,954 INFO] Translating shard 0.
# [2021-11-12 21:19:26,810 INFO] PRED AVG SCORE: -0.5183, PRED PPL: 1.6792
# [2021-11-12 21:19:26,823 INFO] Translating shard 0.
# [2021-11-12 21:19:28,797 INFO] PRED AVG SCORE: -0.7159, PRED PPL: 2.0460
# [2021-11-12 21:19:29,162 INFO] Translating shard 0.
# [2021-11-12 21:19:31,383 INFO] PRED AVG SCORE: -0.5205, PRED PPL: 1.6828
# [2021-11-12 21:19:31,395 INFO] Translating shard 0.
# [2021-11-12 21:19:33,547 INFO] PRED AVG SCORE: -0.7255, PRED PPL: 2.0659
# [2021-11-12 21:19:33,919 INFO] Translating shard 0.
# [2021-11-12 21:19:35,804 INFO] PRED AVG SCORE: -0.5293, PRED PPL: 1.6977
# [2021-11-12 21:19:35,825 INFO] Translating shard 0.
# [2021-11-12 21:19:37,944 INFO] PRED AVG SCORE: -0.7081, PRED PPL: 2.0301
# [2021-11-12 21:19:38,353 INFO] Translating shard 0.
# [2021-11-12 21:19:40,032 INFO] PRED AVG SCORE: -0.5092, PRED PPL: 1.6639
# [2021-11-12 21:19:40,044 INFO] Translating shard 0.
# [2021-11-12 21:19:41,971 INFO] PRED AVG SCORE: -0.7184, PRED PPL: 2.0512
# [2021-11-12 21:19:42,295 INFO] Translating shard 0.
# [2021-11-12 21:19:44,255 INFO] PRED AVG SCORE: -0.5121, PRED PPL: 1.6687
# [2021-11-12 21:19:44,267 INFO] Translating shard 0.
# [2021-11-12 21:19:46,482 INFO] PRED AVG SCORE: -0.7184, PRED PPL: 2.0511
# [2021-11-12 21:19:46,812 INFO] Translating shard 0.
# [2021-11-12 21:19:48,535 INFO] PRED AVG SCORE: -0.5205, PRED PPL: 1.6829
# [2021-11-12 21:19:48,546 INFO] Translating shard 0.
# [2021-11-12 21:19:50,516 INFO] PRED AVG SCORE: -0.7243, PRED PPL: 2.0634
# [2021-11-12 21:19:50,847 INFO] Translating shard 0.
# [2021-11-12 21:19:52,551 INFO] PRED AVG SCORE: -0.5100, PRED PPL: 1.6653
# [2021-11-12 21:19:52,570 INFO] Translating shard 0.
# [2021-11-12 21:19:54,456 INFO] PRED AVG SCORE: -0.7152, PRED PPL: 2.0446
# [2021-11-12 21:19:54,820 INFO] Translating shard 0.
# [2021-11-12 21:19:56,545 INFO] PRED AVG SCORE: -0.5031, PRED PPL: 1.6538
# [2021-11-12 21:19:56,566 INFO] Translating shard 0.
# [2021-11-12 21:19:58,508 INFO] PRED AVG SCORE: -0.6983, PRED PPL: 2.0104
# [2021-11-12 21:19:58,897 INFO] Translating shard 0.
# [2021-11-12 21:20:01,073 INFO] PRED AVG SCORE: -0.5193, PRED PPL: 1.6809
# [2021-11-12 21:20:01,087 INFO] Translating shard 0.
# [2021-11-12 21:20:03,424 INFO] PRED AVG SCORE: -0.7210, PRED PPL: 2.0564
# [2021-11-12 21:20:03,852 INFO] Translating shard 0.
# [2021-11-12 21:20:06,015 INFO] PRED AVG SCORE: -0.5079, PRED PPL: 1.6618
# [2021-11-12 21:20:06,038 INFO] Translating shard 0.
# [2021-11-12 21:20:08,201 INFO] PRED AVG SCORE: -0.7154, PRED PPL: 2.0450
# [2021-11-12 21:20:08,557 INFO] Translating shard 0.
# [2021-11-12 21:20:10,277 INFO] PRED AVG SCORE: -0.5230, PRED PPL: 1.6871
# [2021-11-12 21:20:10,293 INFO] Translating shard 0.
# [2021-11-12 21:20:12,202 INFO] PRED AVG SCORE: -0.7054, PRED PPL: 2.0246
# [2021-11-12 21:20:12,540 INFO] Translating shard 0.
# [2021-11-12 21:20:14,407 INFO] PRED AVG SCORE: -0.5110, PRED PPL: 1.6669
# [2021-11-12 21:20:14,426 INFO] Translating shard 0.
# [2021-11-12 21:20:16,856 INFO] PRED AVG SCORE: -0.7192, PRED PPL: 2.0528
# [2021-11-12 21:20:17,274 INFO] Translating shard 0.
# [2021-11-12 21:20:19,060 INFO] PRED AVG SCORE: -0.5146, PRED PPL: 1.6730
# [2021-11-12 21:20:19,081 INFO] Translating shard 0.
# [2021-11-12 21:20:20,983 INFO] PRED AVG SCORE: -0.7192, PRED PPL: 2.0528
# [2021-11-12 21:20:21,380 INFO] Translating shard 0.
# [2021-11-12 21:20:23,091 INFO] PRED AVG SCORE: -0.5183, PRED PPL: 1.6792
# [2021-11-12 21:20:23,113 INFO] Translating shard 0.
# [2021-11-12 21:20:24,844 INFO] PRED AVG SCORE: -0.7193, PRED PPL: 2.0530
# [2021-11-12 21:20:25,228 INFO] Translating shard 0.
# [2021-11-12 21:20:27,020 INFO] PRED AVG SCORE: -0.5231, PRED PPL: 1.6872
# [2021-11-12 21:20:27,040 INFO] Translating shard 0.
# [2021-11-12 21:20:29,097 INFO] PRED AVG SCORE: -0.7154, PRED PPL: 2.0450
# [2021-11-12 21:20:29,428 INFO] Translating shard 0.
# [2021-11-12 21:20:31,181 INFO] PRED AVG SCORE: -0.5229, PRED PPL: 1.6869
# [2021-11-12 21:20:31,193 INFO] Translating shard 0.
# [2021-11-12 21:20:33,205 INFO] PRED AVG SCORE: -0.7197, PRED PPL: 2.0539
# [2021-11-12 21:20:33,591 INFO] Translating shard 0.
# [2021-11-12 21:20:35,391 INFO] PRED AVG SCORE: -0.5223, PRED PPL: 1.6859
# [2021-11-12 21:20:35,402 INFO] Translating shard 0.
# [2021-11-12 21:20:37,273 INFO] PRED AVG SCORE: -0.7092, PRED PPL: 2.0323
# [2021-11-12 21:20:37,606 INFO] Translating shard 0.
# [2021-11-12 21:20:39,405 INFO] PRED AVG SCORE: -0.4932, PRED PPL: 1.6376
# [2021-11-12 21:20:39,417 INFO] Translating shard 0.
# [2021-11-12 21:20:41,481 INFO] PRED AVG SCORE: -0.6952, PRED PPL: 2.0040
# [2021-11-12 21:20:41,827 INFO] Translating shard 0.
# [2021-11-12 21:20:43,534 INFO] PRED AVG SCORE: -0.5108, PRED PPL: 1.6666
# [2021-11-12 21:20:43,545 INFO] Translating shard 0.
# [2021-11-12 21:20:45,874 INFO] PRED AVG SCORE: -0.7245, PRED PPL: 2.0637
# [2021-11-12 21:20:46,230 INFO] Translating shard 0.
# [2021-11-12 21:20:48,198 INFO] PRED AVG SCORE: -0.5243, PRED PPL: 1.6893
# [2021-11-12 21:20:48,210 INFO] Translating shard 0.
# [2021-11-12 21:20:50,437 INFO] PRED AVG SCORE: -0.7244, PRED PPL: 2.0635
# [2021-11-12 21:20:50,797 INFO] Translating shard 0.
# [2021-11-12 21:20:52,539 INFO] PRED AVG SCORE: -0.5219, PRED PPL: 1.6852
# [2021-11-12 21:20:52,562 INFO] Translating shard 0.
# [2021-11-12 21:20:54,431 INFO] PRED AVG SCORE: -0.7246, PRED PPL: 2.0639
# [2021-11-12 21:20:54,843 INFO] Translating shard 0.
# [2021-11-12 21:20:56,689 INFO] PRED AVG SCORE: -0.5127, PRED PPL: 1.6698
# [2021-11-12 21:20:56,712 INFO] Translating shard 0.
# [2021-11-12 21:20:58,658 INFO] PRED AVG SCORE: -0.7022, PRED PPL: 2.0182
# [2021-11-12 21:20:59,021 INFO] Translating shard 0.
# [2021-11-12 21:21:00,707 INFO] PRED AVG SCORE: -0.5136, PRED PPL: 1.6713
# [2021-11-12 21:21:00,717 INFO] Translating shard 0.
# [2021-11-12 21:21:02,666 INFO] PRED AVG SCORE: -0.7118, PRED PPL: 2.0377
# [2021-11-12 21:21:03,041 INFO] Translating shard 0.
# [2021-11-12 21:21:04,870 INFO] PRED AVG SCORE: -0.5138, PRED PPL: 1.6716
# [2021-11-12 21:21:04,882 INFO] Translating shard 0.
# [2021-11-12 21:21:06,875 INFO] PRED AVG SCORE: -0.7150, PRED PPL: 2.0441
# [2021-11-12 21:21:07,301 INFO] Translating shard 0.
# [2021-11-12 21:21:09,188 INFO] PRED AVG SCORE: -0.5206, PRED PPL: 1.6830
# [2021-11-12 21:21:09,201 INFO] Translating shard 0.
# [2021-11-12 21:21:11,656 INFO] PRED AVG SCORE: -0.7127, PRED PPL: 2.0395
# [2021-11-12 21:21:12,055 INFO] Translating shard 0.
# [2021-11-12 21:21:13,917 INFO] PRED AVG SCORE: -0.5201, PRED PPL: 1.6823
# [2021-11-12 21:21:13,939 INFO] Translating shard 0.
# [2021-11-12 21:21:16,055 INFO] PRED AVG SCORE: -0.7154, PRED PPL: 2.0449
# [2021-11-12 21:21:16,480 INFO] Translating shard 0.
# [2021-11-12 21:21:18,237 INFO] PRED AVG SCORE: -0.5144, PRED PPL: 1.6727
# [2021-11-12 21:21:18,250 INFO] Translating shard 0.
# [2021-11-12 21:21:20,266 INFO] PRED AVG SCORE: -0.7178, PRED PPL: 2.0500
# [2021-11-12 21:21:20,670 INFO] Translating shard 0.
# [2021-11-12 21:21:22,429 INFO] PRED AVG SCORE: -0.5349, PRED PPL: 1.7073
# [2021-11-12 21:21:22,450 INFO] Translating shard 0.
# [2021-11-12 21:21:24,396 INFO] PRED AVG SCORE: -0.7294, PRED PPL: 2.0737
# [2021-11-12 21:21:24,798 INFO] Translating shard 0.
# [2021-11-12 21:21:26,727 INFO] PRED AVG SCORE: -0.5119, PRED PPL: 1.6685
# [2021-11-12 21:21:26,740 INFO] Translating shard 0.
# ...
# [2021-11-12 23:01:54,810 INFO] Translating shard 0.
# [2021-11-12 23:01:56,582 INFO] PRED AVG SCORE: -0.5018, PRED PPL: 1.6517
# [2021-11-12 23:01:56,596 INFO] Translating shard 0.
# [2021-11-12 23:01:58,564 INFO] PRED AVG SCORE: -0.6928, PRED PPL: 1.9994
# [2021-11-12 23:01:58,984 INFO] Translating shard 0.
# [2021-11-12 23:02:00,881 INFO] PRED AVG SCORE: -0.5108, PRED PPL: 1.6666
# [2021-11-12 23:02:00,894 INFO] Translating shard 0.
# [2021-11-12 23:02:02,859 INFO] PRED AVG SCORE: -0.7101, PRED PPL: 2.0342
# [2021-11-12 23:02:03,233 INFO] Translating shard 0.
# [2021-11-12 23:02:05,309 INFO] PRED AVG SCORE: -0.5063, PRED PPL: 1.6592
# [2021-11-12 23:02:05,322 INFO] Translating shard 0.
# [2021-11-12 23:02:07,588 INFO] PRED AVG SCORE: -0.7143, PRED PPL: 2.0428
# [2021-11-12 23:02:08,017 INFO] Translating shard 0.
# [2021-11-12 23:02:10,091 INFO] PRED AVG SCORE: -0.5171, PRED PPL: 1.6772
# [2021-11-12 23:02:10,103 INFO] Translating shard 0.
# [2021-11-12 23:02:12,700 INFO] PRED AVG SCORE: -0.7259, PRED PPL: 2.0665
# [2021-11-12 23:02:13,137 INFO] Translating shard 0.
# [2021-11-12 23:02:14,992 INFO] PRED AVG SCORE: -0.5099, PRED PPL: 1.6651
# [2021-11-12 23:02:15,005 INFO] Translating shard 0.
# [2021-11-12 23:02:16,943 INFO] PRED AVG SCORE: -0.7008, PRED PPL: 2.0154
# [2021-11-12 23:02:17,288 INFO] Translating shard 0.
# [2021-11-12 23:02:19,307 INFO] PRED AVG SCORE: -0.5020, PRED PPL: 1.6520
# [2021-11-12 23:02:19,329 INFO] Translating shard 0.
# [2021-11-12 23:02:21,409 INFO] PRED AVG SCORE: -0.7011, PRED PPL: 2.0159
# [2021-11-12 23:02:21,811 INFO] Translating shard 0.
# [2021-11-12 23:02:23,807 INFO] PRED AVG SCORE: -0.5214, PRED PPL: 1.6843
# [2021-11-12 23:02:23,829 INFO] Translating shard 0.
# [2021-11-12 23:02:25,757 INFO] PRED AVG SCORE: -0.6958, PRED PPL: 2.0053
# [2021-11-12 23:02:26,096 INFO] Translating shard 0.
# [2021-11-12 23:02:27,890 INFO] PRED AVG SCORE: -0.5057, PRED PPL: 1.6582
# [2021-11-12 23:02:27,901 INFO] Translating shard 0.
# [2021-11-12 23:02:29,873 INFO] PRED AVG SCORE: -0.7114, PRED PPL: 2.0369
# [2021-11-12 23:02:30,202 INFO] Translating shard 0.
# [2021-11-12 23:02:32,132 INFO] PRED AVG SCORE: -0.5253, PRED PPL: 1.6909
# [2021-11-12 23:02:32,143 INFO] Translating shard 0.
# [2021-11-12 23:02:34,786 INFO] PRED AVG SCORE: -0.7209, PRED PPL: 2.0563
# [2021-11-12 23:02:35,192 INFO] Translating shard 0.
# [2021-11-12 23:02:37,173 INFO] PRED AVG SCORE: -0.5091, PRED PPL: 1.6637
# [2021-11-12 23:02:37,187 INFO] Translating shard 0.
# [2021-11-12 23:02:39,314 INFO] PRED AVG SCORE: -0.7092, PRED PPL: 2.0324
# [2021-11-12 23:02:39,708 INFO] Translating shard 0.
# [2021-11-12 23:02:41,590 INFO] PRED AVG SCORE: -0.5054, PRED PPL: 1.6577
# [2021-11-12 23:02:41,602 INFO] Translating shard 0.
# [2021-11-12 23:02:43,719 INFO] PRED AVG SCORE: -0.7143, PRED PPL: 2.0427
# [2021-11-12 23:02:44,137 INFO] Translating shard 0.
# [2021-11-12 23:02:45,882 INFO] PRED AVG SCORE: -0.5178, PRED PPL: 1.6784
# [2021-11-12 23:02:45,895 INFO] Translating shard 0.
# [2021-11-12 23:02:47,891 INFO] PRED AVG SCORE: -0.7159, PRED PPL: 2.0460
# [2021-11-12 23:02:48,277 INFO] Translating shard 0.
# [2021-11-12 23:02:50,050 INFO] PRED AVG SCORE: -0.5313, PRED PPL: 1.7012
# [2021-11-12 23:02:50,061 INFO] Translating shard 0.
# [2021-11-12 23:02:51,988 INFO] PRED AVG SCORE: -0.7236, PRED PPL: 2.0619
# [2021-11-12 23:02:52,351 INFO] Translating shard 0.
# [2021-11-12 23:02:54,008 INFO] PRED AVG SCORE: -0.5151, PRED PPL: 1.6738
# [2021-11-12 23:02:54,020 INFO] Translating shard 0.
# [2021-11-12 23:02:55,944 INFO] PRED AVG SCORE: -0.7186, PRED PPL: 2.0516
# [2021-11-12 23:02:56,306 INFO] Translating shard 0.
# [2021-11-12 23:02:57,973 INFO] PRED AVG SCORE: -0.5240, PRED PPL: 1.6887
# [2021-11-12 23:02:57,984 INFO] Translating shard 0.
# [2021-11-12 23:02:59,734 INFO] PRED AVG SCORE: -0.7163, PRED PPL: 2.0468
# [2021-11-12 23:03:00,069 INFO] Translating shard 0.
# [2021-11-12 23:03:01,861 INFO] PRED AVG SCORE: -0.5118, PRED PPL: 1.6683
# [2021-11-12 23:03:01,873 INFO] Translating shard 0.
# [2021-11-12 23:03:03,778 INFO] PRED AVG SCORE: -0.7178, PRED PPL: 2.0499
# [2021-11-12 23:03:04,183 INFO] Translating shard 0.
# [2021-11-12 23:03:06,214 INFO] PRED AVG SCORE: -0.5098, PRED PPL: 1.6649
# [2021-11-12 23:03:06,235 INFO] Translating shard 0.
# [2021-11-12 23:03:08,239 INFO] PRED AVG SCORE: -0.7184, PRED PPL: 2.0511
# [2021-11-12 23:03:08,584 INFO] Translating shard 0.
# [2021-11-12 23:03:10,303 INFO] PRED AVG SCORE: -0.5200, PRED PPL: 1.6821
# [2021-11-12 23:03:10,316 INFO] Translating shard 0.
# [2021-11-12 23:03:12,119 INFO] PRED AVG SCORE: -0.7145, PRED PPL: 2.0432
# [2021-11-12 23:03:12,516 INFO] Translating shard 0.
# [2021-11-12 23:03:14,489 INFO] PRED AVG SCORE: -0.5205, PRED PPL: 1.6829
# [2021-11-12 23:03:14,503 INFO] Translating shard 0.
# [2021-11-12 23:03:16,772 INFO] PRED AVG SCORE: -0.7195, PRED PPL: 2.0533
# [2021-11-12 23:03:17,207 INFO] Translating shard 0.
# [2021-11-12 23:03:19,073 INFO] PRED AVG SCORE: -0.5195, PRED PPL: 1.6812
# [2021-11-12 23:03:19,095 INFO] Translating shard 0.
# [2021-11-12 23:03:21,070 INFO] PRED AVG SCORE: -0.7083, PRED PPL: 2.0305
# [2021-11-12 23:03:21,483 INFO] Translating shard 0.
# [2021-11-12 23:03:23,216 INFO] PRED AVG SCORE: -0.5142, PRED PPL: 1.6722
# [2021-11-12 23:03:23,229 INFO] Translating shard 0.
# [2021-11-12 23:03:25,260 INFO] PRED AVG SCORE: -0.7072, PRED PPL: 2.0284
# [2021-11-12 23:03:25,672 INFO] Translating shard 0.
# [2021-11-12 23:03:27,740 INFO] PRED AVG SCORE: -0.5175, PRED PPL: 1.6779
# [2021-11-12 23:03:27,755 INFO] Translating shard 0.
# [2021-11-12 23:03:29,904 INFO] PRED AVG SCORE: -0.7258, PRED PPL: 2.0663
# [2021-11-12 23:03:30,327 INFO] Translating shard 0.
# [2021-11-12 23:03:32,375 INFO] PRED AVG SCORE: -0.5080, PRED PPL: 1.6620
# [2021-11-12 23:03:32,389 INFO] Translating shard 0.
# [2021-11-12 23:03:34,521 INFO] PRED AVG SCORE: -0.6944, PRED PPL: 2.0026
# [2021-11-12 23:03:34,928 INFO] Translating shard 0.
# [2021-11-12 23:03:36,680 INFO] PRED AVG SCORE: -0.5138, PRED PPL: 1.6717
# [2021-11-12 23:03:36,693 INFO] Translating shard 0.
# [2021-11-12 23:03:39,134 INFO] PRED AVG SCORE: -0.7166, PRED PPL: 2.0474
# [2021-11-12 23:03:39,506 INFO] Translating shard 0.
# [2021-11-12 23:03:41,642 INFO] PRED AVG SCORE: -0.5222, PRED PPL: 1.6858
# [2021-11-12 23:03:41,656 INFO] Translating shard 0.
# [2021-11-12 23:03:43,891 INFO] PRED AVG SCORE: -0.7222, PRED PPL: 2.0590
# [2021-11-12 23:03:44,279 INFO] Translating shard 0.
# [2021-11-12 23:03:46,144 INFO] PRED AVG SCORE: -0.4980, PRED PPL: 1.6455
# [2021-11-12 23:03:46,158 INFO] Translating shard 0.
# [2021-11-12 23:03:48,155 INFO] PRED AVG SCORE: -0.6943, PRED PPL: 2.0023
# [2021-11-12 23:03:48,600 INFO] Translating shard 0.
# [2021-11-12 23:03:51,044 INFO] PRED AVG SCORE: -0.5128, PRED PPL: 1.6699
# [2021-11-12 23:03:51,067 INFO] Translating shard 0.
# [2021-11-12 23:03:53,182 INFO] PRED AVG SCORE: -0.7150, PRED PPL: 2.0442
# [2021-11-12 23:03:53,613 INFO] Translating shard 0.
# [2021-11-12 23:03:55,471 INFO] PRED AVG SCORE: -0.5180, PRED PPL: 1.6787
# [2021-11-12 23:03:55,485 INFO] Translating shard 0.
# [2021-11-12 23:03:58,094 INFO] PRED AVG SCORE: -0.7358, PRED PPL: 2.0871
# [2021-11-12 23:03:58,542 INFO] Translating shard 0.
# [2021-11-12 23:04:00,491 INFO] PRED AVG SCORE: -0.5162, PRED PPL: 1.6756
# [2021-11-12 23:04:00,504 INFO] Translating shard 0.
# [2021-11-12 23:04:02,533 INFO] PRED AVG SCORE: -0.7082, PRED PPL: 2.0304
# [2021-11-12 23:04:02,928 INFO] Translating shard 0.
# [2021-11-12 23:04:04,987 INFO] PRED AVG SCORE: -0.5135, PRED PPL: 1.6711
# [2021-11-12 23:04:05,001 INFO] Translating shard 0.
# [2021-11-12 23:04:06,979 INFO] PRED AVG SCORE: -0.7086, PRED PPL: 2.0310
# [2021-11-12 23:04:07,408 INFO] Translating shard 0.
# [2021-11-12 23:04:09,527 INFO] PRED AVG SCORE: -0.5225, PRED PPL: 1.6862
# [2021-11-12 23:04:09,541 INFO] Translating shard 0.
# [2021-11-12 23:04:11,597 INFO] PRED AVG SCORE: -0.7279, PRED PPL: 2.0707
# [2021-11-12 23:04:11,973 INFO] Translating shard 0.
# [2021-11-12 23:04:14,140 INFO] PRED AVG SCORE: -0.5175, PRED PPL: 1.6778
# [2021-11-12 23:04:14,154 INFO] Translating shard 0.
# [2021-11-12 23:04:16,205 INFO] PRED AVG SCORE: -0.7126, PRED PPL: 2.0393
# [2021-11-12 23:04:16,640 INFO] Translating shard 0.
# [2021-11-12 23:04:18,533 INFO] PRED AVG SCORE: -0.5174, PRED PPL: 1.6776
# [2021-11-12 23:04:18,546 INFO] Translating shard 0.
# [2021-11-12 23:04:20,473 INFO] PRED AVG SCORE: -0.7130, PRED PPL: 2.0400
# [2021-11-12 23:04:20,904 INFO] Translating shard 0.
# [2021-11-12 23:04:22,966 INFO] PRED AVG SCORE: -0.5187, PRED PPL: 1.6799
# [2021-11-12 23:04:22,980 INFO] Translating shard 0.
# [2021-11-12 23:04:24,984 INFO] PRED AVG SCORE: -0.6985, PRED PPL: 2.0108
# [2021-11-12 23:04:25,403 INFO] Translating shard 0.
# [2021-11-12 23:04:35,792 INFO] PRED AVG SCORE: -0.5087, PRED PPL: 1.6631
# [2021-11-12 23:04:35,806 INFO] Translating shard 0.
# [2021-11-12 23:04:38,006 INFO] PRED AVG SCORE: -0.7069, PRED PPL: 2.0277
# [2021-11-12 23:04:38,421 INFO] Translating shard 0.
# [2021-11-12 23:04:40,311 INFO] PRED AVG SCORE: -0.5162, PRED PPL: 1.6757
# [2021-11-12 23:04:40,325 INFO] Translating shard 0.
# [2021-11-12 23:04:42,721 INFO] PRED AVG SCORE: -0.7145, PRED PPL: 2.0431
# [2021-11-12 23:04:43,110 INFO] Translating shard 0.
# [2021-11-12 23:04:45,128 INFO] PRED AVG SCORE: -0.5106, PRED PPL: 1.6663
# [2021-11-12 23:04:45,141 INFO] Translating shard 0.
# [2021-11-12 23:04:47,367 INFO] PRED AVG SCORE: -0.7035, PRED PPL: 2.0208
# [2021-11-12 23:04:47,767 INFO] Translating shard 0.
# [2021-11-12 23:04:49,541 INFO] PRED AVG SCORE: -0.5309, PRED PPL: 1.7005
# [2021-11-12 23:04:49,562 INFO] Translating shard 0.
# [2021-11-12 23:04:51,609 INFO] PRED AVG SCORE: -0.7248, PRED PPL: 2.0644
# [2021-11-12 23:04:51,981 INFO] Translating shard 0.
# [2021-11-12 23:04:53,977 INFO] PRED AVG SCORE: -0.5155, PRED PPL: 1.6745
# [2021-11-12 23:04:53,990 INFO] Translating shard 0.
# [2021-11-12 23:04:55,995 INFO] PRED AVG SCORE: -0.7289, PRED PPL: 2.0727
# [2021-11-12 23:04:56,408 INFO] Translating shard 0.
# [2021-11-12 23:04:58,152 INFO] PRED AVG SCORE: -0.5371, PRED PPL: 1.7110
# [2021-11-12 23:04:58,173 INFO] Translating shard 0.
# [2021-11-12 23:05:00,040 INFO] PRED AVG SCORE: -0.7198, PRED PPL: 2.0540
# [2021-11-12 23:05:00,466 INFO] Translating shard 0.
# [2021-11-12 23:05:02,535 INFO] PRED AVG SCORE: -0.5044, PRED PPL: 1.6560
# [2021-11-12 23:05:02,548 INFO] Translating shard 0.
# [2021-11-12 23:05:04,695 INFO] PRED AVG SCORE: -0.6927, PRED PPL: 1.9991
# [2021-11-12 23:05:05,071 INFO] Translating shard 0.
# [2021-11-12 23:05:07,019 INFO] PRED AVG SCORE: -0.5106, PRED PPL: 1.6663
# [2021-11-12 23:05:07,039 INFO] Translating shard 0.
# [2021-11-12 23:05:08,995 INFO] PRED AVG SCORE: -0.7259, PRED PPL: 2.0666
# [2021-11-12 23:05:09,403 INFO] Translating shard 0.
# [2021-11-12 23:05:11,443 INFO] PRED AVG SCORE: -0.5059, PRED PPL: 1.6585
# [2021-11-12 23:05:11,457 INFO] Translating shard 0.
# [2021-11-12 23:05:13,557 INFO] PRED AVG SCORE: -0.7127, PRED PPL: 2.0396
# [2021-11-12 23:05:13,965 INFO] Translating shard 0.
# [2021-11-12 23:05:15,785 INFO] PRED AVG SCORE: -0.5159, PRED PPL: 1.6751
# [2021-11-12 23:05:15,798 INFO] Translating shard 0.
# [2021-11-12 23:05:17,803 INFO] PRED AVG SCORE: -0.7069, PRED PPL: 2.0278
# [2021-11-12 23:05:18,209 INFO] Translating shard 0.
# [2021-11-12 23:05:19,989 INFO] PRED AVG SCORE: -0.5079, PRED PPL: 1.6618
# [2021-11-12 23:05:20,002 INFO] Translating shard 0.
# [2021-11-12 23:05:21,870 INFO] PRED AVG SCORE: -0.7117, PRED PPL: 2.0374
# [2021-11-12 23:05:22,279 INFO] Translating shard 0.
# [2021-11-12 23:05:24,186 INFO] PRED AVG SCORE: -0.5225, PRED PPL: 1.6862
# [2021-11-12 23:05:24,206 INFO] Translating shard 0.
# [2021-11-12 23:05:26,334 INFO] PRED AVG SCORE: -0.7302, PRED PPL: 2.0754
# [2021-11-12 23:05:26,727 INFO] Translating shard 0.
# [2021-11-12 23:05:28,863 INFO] PRED AVG SCORE: -0.5205, PRED PPL: 1.6829
# [2021-11-12 23:05:28,875 INFO] Translating shard 0.
# [2021-11-12 23:05:30,944 INFO] PRED AVG SCORE: -0.7028, PRED PPL: 2.0195
# [2021-11-12 23:05:31,352 INFO] Translating shard 0.
# [2021-11-12 23:05:33,216 INFO] PRED AVG SCORE: -0.5256, PRED PPL: 1.6914
# [2021-11-12 23:05:33,229 INFO] Translating shard 0.
# [2021-11-12 23:05:35,586 INFO] PRED AVG SCORE: -0.7141, PRED PPL: 2.0423
# [2021-11-12 23:05:35,987 INFO] Translating shard 0.
# [2021-11-12 23:05:37,887 INFO] PRED AVG SCORE: -0.5145, PRED PPL: 1.6729
# [2021-11-12 23:05:37,901 INFO] Translating shard 0.
# [2021-11-12 23:05:39,980 INFO] PRED AVG SCORE: -0.7196, PRED PPL: 2.0536
# [2021-11-12 23:05:40,391 INFO] Translating shard 0.
# [2021-11-12 23:05:42,452 INFO] PRED AVG SCORE: -0.5373, PRED PPL: 1.7113
# [2021-11-12 23:05:42,466 INFO] Translating shard 0.
# [2021-11-12 23:05:44,545 INFO] PRED AVG SCORE: -0.7239, PRED PPL: 2.0625
# [2021-11-12 23:05:44,959 INFO] Translating shard 0.
# [2021-11-12 23:05:46,923 INFO] PRED AVG SCORE: -0.5045, PRED PPL: 1.6562
# [2021-11-12 23:05:46,936 INFO] Translating shard 0.
# [2021-11-12 23:05:48,893 INFO] PRED AVG SCORE: -0.7123, PRED PPL: 2.0388
# [2021-11-12 23:05:49,307 INFO] Translating shard 0.
# [2021-11-12 23:05:51,309 INFO] PRED AVG SCORE: -0.5158, PRED PPL: 1.6750
# [2021-11-12 23:05:51,330 INFO] Translating shard 0.
# [2021-11-12 23:05:53,450 INFO] PRED AVG SCORE: -0.7077, PRED PPL: 2.0293
# [2021-11-12 23:05:53,890 INFO] Translating shard 0.
# [2021-11-12 23:05:55,795 INFO] PRED AVG SCORE: -0.5036, PRED PPL: 1.6547
# [2021-11-12 23:05:55,809 INFO] Translating shard 0.
# [2021-11-12 23:05:58,253 INFO] PRED AVG SCORE: -0.6974, PRED PPL: 2.0084
# [2021-11-12 23:05:58,628 INFO] Translating shard 0.
# [2021-11-12 23:06:00,497 INFO] PRED AVG SCORE: -0.5212, PRED PPL: 1.6840
# [2021-11-12 23:06:00,517 INFO] Translating shard 0.
# [2021-11-12 23:06:02,619 INFO] PRED AVG SCORE: -0.7261, PRED PPL: 2.0671
# [2021-11-12 23:06:03,022 INFO] Translating shard 0.
# [2021-11-12 23:06:05,021 INFO] PRED AVG SCORE: -0.5095, PRED PPL: 1.6644
# [2021-11-12 23:06:05,033 INFO] Translating shard 0.
# [2021-11-12 23:06:07,085 INFO] PRED AVG SCORE: -0.7211, PRED PPL: 2.0567
# [2021-11-12 23:06:07,511 INFO] Translating shard 0.
# [2021-11-12 23:06:09,281 INFO] PRED AVG SCORE: -0.5240, PRED PPL: 1.6887
# [2021-11-12 23:06:09,294 INFO] Translating shard 0.
# [2021-11-12 23:06:11,344 INFO] PRED AVG SCORE: -0.7262, PRED PPL: 2.0671
# [2021-11-12 23:06:11,722 INFO] Translating shard 0.
# [2021-11-12 23:06:14,032 INFO] PRED AVG SCORE: -0.5186, PRED PPL: 1.6797
# [2021-11-12 23:06:14,045 INFO] Translating shard 0.
# [2021-11-12 23:06:16,117 INFO] PRED AVG SCORE: -0.7198, PRED PPL: 2.0541
# [2021-11-12 23:06:16,502 INFO] Translating shard 0.
# [2021-11-12 23:06:18,419 INFO] PRED AVG SCORE: -0.5229, PRED PPL: 1.6869
# [2021-11-12 23:06:18,432 INFO] Translating shard 0.
# [2021-11-12 23:06:20,879 INFO] PRED AVG SCORE: -0.7090, PRED PPL: 2.0319
# [2021-11-12 23:06:21,310 INFO] Translating shard 0.
# [2021-11-12 23:06:22,999 INFO] PRED AVG SCORE: -0.5188, PRED PPL: 1.6800
# [2021-11-12 23:06:23,012 INFO] Translating shard 0.
# [2021-11-12 23:06:24,867 INFO] PRED AVG SCORE: -0.7131, PRED PPL: 2.0403
# [2021-11-12 23:06:25,280 INFO] Translating shard 0.
# [2021-11-12 23:06:27,112 INFO] PRED AVG SCORE: -0.5143, PRED PPL: 1.6725
# [2021-11-12 23:06:27,125 INFO] Translating shard 0.
# [2021-11-12 23:06:29,265 INFO] PRED AVG SCORE: -0.7206, PRED PPL: 2.0557
# [2021-11-12 23:06:29,666 INFO] Translating shard 0.
# [2021-11-12 23:06:31,512 INFO] PRED AVG SCORE: -0.5253, PRED PPL: 1.6910
# [2021-11-12 23:06:31,525 INFO] Translating shard 0.
# [2021-11-12 23:06:33,496 INFO] PRED AVG SCORE: -0.7125, PRED PPL: 2.0390
# [2021-11-12 23:06:33,889 INFO] Translating shard 0.
# [2021-11-12 23:06:36,028 INFO] PRED AVG SCORE: -0.5066, PRED PPL: 1.6597
# [2021-11-12 23:06:36,042 INFO] Translating shard 0.
# [2021-11-12 23:06:37,997 INFO] PRED AVG SCORE: -0.7102, PRED PPL: 2.0343
# [2021-11-12 23:06:38,390 INFO] Translating shard 0.
# [2021-11-12 23:06:40,237 INFO] PRED AVG SCORE: -0.5169, PRED PPL: 1.6768
# [2021-11-12 23:06:40,250 INFO] Translating shard 0.
# [2021-11-12 23:06:42,298 INFO] PRED AVG SCORE: -0.7169, PRED PPL: 2.0481
# [2021-11-12 23:06:42,691 INFO] Translating shard 0.
# [2021-11-12 23:06:43,653 INFO] PRED AVG SCORE: -0.4841, PRED PPL: 1.6227
# [2021-11-12 23:06:43,659 INFO] Translating shard 0.
# [2021-11-12 23:06:44,500 INFO] PRED AVG SCORE: -0.6802, PRED PPL: 1.9742

# %%
df = pd.DataFrame({'hun': hun_lines, 'eng': eng_lines, 'hun_translation': translated_hun_lines, 'eng_translation': translated_eng_lines, 'huen_similarity': huen_similarity_scores, 'enhu_similarity': enhu_similarity_scores})

# %%
df
# Out:
#                                                       hun  \
# 0       A Bizottság ezt az információt az Európai Unió...
# 1       A Bizottság ezeket az információkat közli a ta...
# 2       Valamennyi módosító közlemény tartalmazza az ú...
# 3       Az ember sohase találja el a 3. , a 7. , a 13....
# 4       Végül a kulcs képe juttatott eszébe az itteni ...
# ...                                                   ...
# 830643  ( 3 ) Az előlegelszámoló tisztviselő az alábbi...
# 830644  Tuppence dünnyögött megvető kézmozdulatot , s ...
# 830645  U Po Kyin nemtetszése jeléül néhány udvarias s...
# 830646  Megjegyzendő , hogy az említett piaci szegmens...
# 830647                       Egy jó kisfiú 60%-át teszi .
#
#                                                       eng  \
# 0       the commission shall publish this information ...
# 1       the commission shall communicate this informat...
# 2         all revision messages include the ways iv him .
# 3       you can never guess field types 3 , 7 , 13 , 1...
# 4                      the sight of the key reminded it .
# ...                                                   ...
# 830643  the imprest administrator may make a question ...
# 830644  tuppence murmured his hands and went into the ...
# 830645  u po kyin threw up a few pleasant words in dis...
# 830646  it should be noted that these market segments ...
# 830647  thats around 60 % of the community market a go...
#
#                                           hun_translation  \
# 0       a bizottság közzéteszi ezt az információt az e...
# 1       a bizottság közli ezt az információt a tagálla...
# 2                       minden átmeneti üzenet benne van.
# 3       A 3., 7., 13., 14. és 16. mezőtípust nem lehet...
# 4                        a kulcs látványa emlékeztette...
# ...                                                   ...
# 830643  az előlegelszámoló tisztviselő a következők al...
# 830644             Kezét mormolta, és bement az ebédlőbe.
# 830645  u po kyin undorodva feldobott néhány kellemes ...
# 830646  Meg kell jegyezni, hogy ezek a piaci szegmense...
# 830647  Ez körülbelül a közösségi piac 60%-a egy jó fi...
#
#                                           eng_translation  huen_similarity  \
# 0       The Commission publishes this information in t...         0.922374
# 1       The Commission will communicate this informati...         0.953655
# 2       Every revision message contains its paths and ...         0.734506
# 3                    One never finds it on 3, 7, 13, 14 .         0.804653
# 4       Finally, a picture of the key reminded him of ...         0.883965
# ...                                                   ...              ...
# 830643  3 ) The imprest administrator shall do somethi...         0.928219
# 830644  Tuppence murmured a contemptuous gesture and w...         0.899864
# 830645  U Po Kyin spoke a few polite words in displeas...         0.783681
# 830646  It should be noted that these market segments ...         0.943972
# 830647                          It is 60 % of a good boy.         0.857901
#
#         enhu_similarity
# 0              0.777107
# 1              0.897023
# 2              0.451700
# 3              0.530200
# 4              0.613354
# ...                 ...
# 830643         0.833042
# 830644         0.802763
# 830645         0.622425
# 830646         0.799594
# 830647         0.698420
#
# [830648 rows x 6 columns]

# %%
df.to_csv('filtering_test.tsv', sep = '\t', index=False)

# %%
df = pd.read_csv('filtering_test.tsv', sep = '\t')

# %%
df
# Out:
#                                                       hun  \
# 0       A Bizottság ezt az információt az Európai Unió...
# 1       A Bizottság ezeket az információkat közli a ta...
# 2       Valamennyi módosító közlemény tartalmazza az ú...
# 3       Az ember sohase találja el a 3. , a 7. , a 13....
# 4       Végül a kulcs képe juttatott eszébe az itteni ...
# ...                                                   ...
# 830643  ( 3 ) Az előlegelszámoló tisztviselő az alábbi...
# 830644  Tuppence dünnyögött megvető kézmozdulatot , s ...
# 830645  U Po Kyin nemtetszése jeléül néhány udvarias s...
# 830646  Megjegyzendő , hogy az említett piaci szegmens...
# 830647                       Egy jó kisfiú 60%-át teszi .
#
#                                                       eng  \
# 0       the commission shall publish this information ...
# 1       the commission shall communicate this informat...
# 2         all revision messages include the ways iv him .
# 3       you can never guess field types 3 , 7 , 13 , 1...
# 4                      the sight of the key reminded it .
# ...                                                   ...
# 830643  the imprest administrator may make a question ...
# 830644  tuppence murmured his hands and went into the ...
# 830645  u po kyin threw up a few pleasant words in dis...
# 830646  it should be noted that these market segments ...
# 830647  thats around 60 % of the community market a go...
#
#                                           hun_translation  \
# 0       a bizottság közzéteszi ezt az információt az e...
# 1       a bizottság közli ezt az információt a tagálla...
# 2                       minden átmeneti üzenet benne van.
# 3       A 3., 7., 13., 14. és 16. mezőtípust nem lehet...
# 4                        a kulcs látványa emlékeztette...
# ...                                                   ...
# 830643  az előlegelszámoló tisztviselő a következők al...
# 830644             Kezét mormolta, és bement az ebédlőbe.
# 830645  u po kyin undorodva feldobott néhány kellemes ...
# 830646  Meg kell jegyezni, hogy ezek a piaci szegmense...
# 830647  Ez körülbelül a közösségi piac 60%-a egy jó fi...
#
#                                           eng_translation  huen_similarity  \
# 0       The Commission publishes this information in t...         0.922374
# 1       The Commission will communicate this informati...         0.953655
# 2       Every revision message contains its paths and ...         0.734506
# 3                    One never finds it on 3, 7, 13, 14 .         0.804653
# 4       Finally, a picture of the key reminded him of ...         0.883965
# ...                                                   ...              ...
# 830643  3 ) The imprest administrator shall do somethi...         0.928219
# 830644  Tuppence murmured a contemptuous gesture and w...         0.899864
# 830645  U Po Kyin spoke a few polite words in displeas...         0.783681
# 830646  It should be noted that these market segments ...         0.943972
# 830647                          It is 60 % of a good boy.         0.857901
#
#         enhu_similarity
# 0              0.777107
# 1              0.897023
# 2              0.451700
# 3              0.530200
# 4              0.613354
# ...                 ...
# 830643         0.833042
# 830644         0.802763
# 830645         0.622425
# 830646         0.799594
# 830647         0.698420
#
# [830648 rows x 6 columns]

# %%
sns.histplot(df['huen_similarity'])
# Out:
# <AxesSubplot:xlabel='huen_similarity', ylabel='Count'>

# %%
sns.histplot(df['enhu_similarity'])
# Out:
# <AxesSubplot:xlabel='enhu_similarity', ylabel='Count'>

# %%
def get_basic_stats(df, col):
    metric_dict = {}
    metric_dict['q0.001'] = df[col].quantile(q=0.001)
    metric_dict['q0.01'] = df[col].quantile(q=0.01)
    metric_dict['q0.25'] = df[col].quantile(q=0.25)
    metric_dict['q0.5'] = df[col].quantile(q=0.5)
    metric_dict['q0.75'] = df[col].quantile(q=0.75)
    metric_dict['q0.99'] = df[col].quantile(q=0.99)
    metric_dict['q0.999'] = df[col].quantile(q=0.999)
    metric_dict['min'] = df[col].min()
    metric_dict['max'] = df[col].max()
    metric_dict['mean'] = df[col].mean()
    metric_dict['stdev'] = df[col].std()
    
    return metric_dict

# %%
huen_similarity_metrics = get_basic_stats(df, 'huen_similarity')
huen_similarity_metrics
# Out:
# {'q0.001': 0.2626877446770668,
#  'q0.01': 0.43335984259843824,
#  'q0.25': 0.730378270149231,
#  'q0.5': 0.8165398836135864,
#  'q0.75': 0.8815585672855377,
#  'q0.99': 0.9635053312778473,
#  'q0.999': 0.9795788632035256,
#  'min': -0.07363514602184296,
#  'max': 1.0,
#  'mean': 0.7939657490495609,
#  'stdev': 0.11678799539447605}

# %%
enhu_similarity_metrics = get_basic_stats(df, 'enhu_similarity')
enhu_similarity_metrics
# Out:
# {'q0.001': 0.15463465452194214,
#  'q0.01': 0.3074034070968628,
#  'q0.25': 0.6408174633979797,
#  'q0.5': 0.742557168006897,
#  'q0.75': 0.8233204632997513,
#  'q0.99': 0.9376656275987625,
#  'q0.999': 0.9642316173911095,
#  'min': -0.24618439376354215,
#  'max': 1.0000001192092896,
#  'mean': 0.7197353069042347,
#  'stdev': 0.13862667650430524}

# %%
pd.options.display.max_colwidth = 200

# %%
df[
    (df['huen_similarity'] > huen_similarity_metrics['q0.01'])
    & (df['huen_similarity'] < huen_similarity_metrics['q0.25'])
    & (df['enhu_similarity'] > enhu_similarity_metrics['q0.01'])
    & (df['enhu_similarity'] < enhu_similarity_metrics['q0.25'])
]
# Out:
#                                                             hun  \
# 24                                 Úristen , tagságát művelsz ?
# 27                                    Ned megismételte a fiút .
# 28                                      Mildred megérezte Ezt .
# 37                     Philip lefejtette magáról az érzéseket .
# 41                       Zsákos Bilbó a rendszámtáblát utálja !
# ...                                                         ...
# 830575                        Én mindenből csak magát gyűjtöm .
# 830577                sok minden furcsaságot untat az ilyesmi .
# 830603               Dick szemüvegét nem mondhatta el magáról .
# 830605  + az építési anyagok tárolása a nevét tovább rontotta ,
# 830623                          Frics , kérem ezt az állást ...
#
#                                                                                      eng  \
# 24                    god , man , its membership of the imi joint undertaking you doin ?
# 27                                                              ned told the boy again .
# 28                                                          she would feel it upon her .
# 37                                                            he released him from her .
# 41                                         thats the license plate bilbo baggins hates !
# ...                                                                                  ...
# 830575                                                         i collect a firmer grip .
# 830577                                                              that will bore you .
# 830603                                                dick could not claim his glasses .
# 830605  the storing of building materials makes little or nothing about her even worse ,
# 830623                                       now , filch , if youll just give me the job
#
#                                                           hun_translation  \
# 24      Istenem, ember, ez a tagsága annak a cégnek, amelyre vállalkozol?
# 27                                                 ...megmondta a fiúnak.
# 28                                                        Érezni fogja...
# 37                                                   Elengedte a lánytól.
# 41                              Ez a rendszámtábla bilbo baggins gyűlöli!
# ...                                                                   ...
# 830575                                          Erősebb fogást gyűjtök...
# 830577                                                          Ez untat.
# 830603                            A farok nem követelheti a szemüvegét...
# 830605     az építőanyagok tárolása nem tesz semmit, vagy még rosszabbat,
# 830623                                Most, filch, ha ideadná a munkát...
#
#                                              eng_translation  huen_similarity  \
# 24                         My God, are you doing membership?         0.686370
# 27                                     Ned repeated the boy.         0.688298
# 28                                        Mildred felt this.         0.587823
# 37                         Philip stripped off his feelings.         0.662533
# 41                            Bilbo Baggins hates the plate!         0.634404
# ...                                                      ...              ...
# 830575                        I collect you from everything.         0.656734
# 830577              There is much oddness about such things.         0.616490
# 830603                        He couldnt tell Dicks glasses.         0.703298
# 830605  storage of construction materials worsened his name,         0.657926
# 830623                                Filch, please this job         0.597563
#
#         enhu_similarity
# 24             0.521931
# 27             0.540274
# 28             0.431739
# 37             0.424457
# 41             0.625492
# ...                 ...
# 830575         0.426465
# 830577         0.545495
# 830603         0.584707
# 830605         0.595248
# 830623         0.582793
#
# [105717 rows x 6 columns]

# %%
df[
    (df['huen_similarity'] > huen_similarity_metrics['q0.01'])
    & (df['huen_similarity'] < huen_similarity_metrics['q0.25'])
    & (df['enhu_similarity'] > enhu_similarity_metrics['q0.01'])
    & (df['enhu_similarity'] < enhu_similarity_metrics['q0.25'])
]
# Out:
#                                                             hun  \
# 24                                 Úristen , tagságát művelsz ?
# 27                                    Ned megismételte a fiút .
# 28                                      Mildred megérezte Ezt .
# 37                     Philip lefejtette magáról az érzéseket .
# 41                       Zsákos Bilbó a rendszámtáblát utálja !
# ...                                                         ...
# 830575                        Én mindenből csak magát gyűjtöm .
# 830577                sok minden furcsaságot untat az ilyesmi .
# 830603               Dick szemüvegét nem mondhatta el magáról .
# 830605  + az építési anyagok tárolása a nevét tovább rontotta ,
# 830623                          Frics , kérem ezt az állást ...
#
#                                                                                      eng  \
# 24                    god , man , its membership of the imi joint undertaking you doin ?
# 27                                                              ned told the boy again .
# 28                                                          she would feel it upon her .
# 37                                                            he released him from her .
# 41                                         thats the license plate bilbo baggins hates !
# ...                                                                                  ...
# 830575                                                         i collect a firmer grip .
# 830577                                                              that will bore you .
# 830603                                                dick could not claim his glasses .
# 830605  the storing of building materials makes little or nothing about her even worse ,
# 830623                                       now , filch , if youll just give me the job
#
#                                                           hun_translation  \
# 24      Istenem, ember, ez a tagsága annak a cégnek, amelyre vállalkozol?
# 27                                                 ...megmondta a fiúnak.
# 28                                                        Érezni fogja...
# 37                                                   Elengedte a lánytól.
# 41                              Ez a rendszámtábla bilbo baggins gyűlöli!
# ...                                                                   ...
# 830575                                          Erősebb fogást gyűjtök...
# 830577                                                          Ez untat.
# 830603                            A farok nem követelheti a szemüvegét...
# 830605     az építőanyagok tárolása nem tesz semmit, vagy még rosszabbat,
# 830623                                Most, filch, ha ideadná a munkát...
#
#                                              eng_translation  huen_similarity  \
# 24                         My God, are you doing membership?         0.686370
# 27                                     Ned repeated the boy.         0.688298
# 28                                        Mildred felt this.         0.587823
# 37                         Philip stripped off his feelings.         0.662533
# 41                            Bilbo Baggins hates the plate!         0.634404
# ...                                                      ...              ...
# 830575                        I collect you from everything.         0.656734
# 830577              There is much oddness about such things.         0.616490
# 830603                        He couldnt tell Dicks glasses.         0.703298
# 830605  storage of construction materials worsened his name,         0.657926
# 830623                                Filch, please this job         0.597563
#
#         enhu_similarity  hu_word_count  en_word_count
# 24             0.521931            7.5           10.0
# 27             0.540274            4.0            5.0
# 28             0.431739            3.0            5.0
# 37             0.424457            4.5            5.5
# 41             0.625492            6.0            6.5
# ...                 ...            ...            ...
# 830575         0.426465            4.5            5.5
# 830577         0.545495            4.5            6.0
# 830603         0.584707            6.5            6.0
# 830605         0.595248            9.5           10.5
# 830623         0.582793            6.5            7.5
#
# [105717 rows x 8 columns]

# %%
df[
    (df['huen_similarity'] > huen_similarity_metrics['q0.25'])
    & (df['enhu_similarity'] > enhu_similarity_metrics['q0.25'])
]
# Out:
#                                                                                                                                                hun  \
# 0                                                        A Bizottság ezt az információt az Európai Unió Hivatalos Lapja C sorozatában hirdeti ki .
# 1                                                                         A Bizottság ezeket az információkat közli a tagállamok vámhatóságaival .
# 6                                     ( 3 ) A bizottság maga állapítja meg a Kombinált Nómenklatúra értelmezésére irányadó általános szabályokat .
# 8                                                            Csakhogy a naptár pontatlanul jelezte az alkalmazandó minőségértékelési eljárásokat .
# 9                                         ( 15 ) Ez a rendelet a 2005/32/EK irányelv 8. cikkével összhangban meghatározza a napnyugta időpontját .
# ...                                                                                                                                            ...
# 830641         ( 9 ) Az igazgatási tevékenységek különböző területein a számítógépes eljárások használata fokozatosan felváltja tőled segítséget .
# 830643  ( 3 ) Az előlegelszámoló tisztviselő az alábbiak alapján és a következő határok között jogosult harmadik személy részére valamit végezni :
# 830644                                                                          Tuppence dünnyögött megvető kézmozdulatot , s bement az ebédlőbe .
# 830646                                    Megjegyzendő , hogy az említett piaci szegmensek mennyiségi szempontból a közösségi piac ezt teszik ki .
# 830647                                                                                                                Egy jó kisfiú 60%-át teszi .
#
#                                                                                                                                      eng  \
# 0                          the commission shall publish this information in the c series of the official journal of the european union .
# 1                                    the commission shall communicate this information to the customs authorities of the member states .
# 6                                                                                         the committee shall adopt the general rules ..
# 8                              but the applicable conformity assessment procedures the air force colonel had consulted related to 1961 .
# 9                          ( 15 ) in accordance with article 8 of directive 2005/32 / ec , this regulation should specify the calendar .
# ...                                                                                                                                  ...
# 830641  ( 9 ) the use of computerised procedures is gradually replacing little juice in the different areas of administrative activity .
# 830643                                             the imprest administrator may make a question on the basis and within the limits of :
# 830644                                                                       tuppence murmured his hands and went into the dining room .
# 830646                                                    it should be noted that these market segments represent what in volume terms .
# 830647                                                                  thats around 60 % of the community market a good son has to do .
#
#                                                                                                                              hun_translation  \
# 0                                      a bizottság közzéteszi ezt az információt az európeai szakszervezet hivatalos lapjának c sorozatában.
# 1                                                                         a bizottság közli ezt az információt a tagállamok vámhatóságaival.
# 6                                                                                            A bizottság elfogadja az általános szabályokat.
# 8                                        de az alkalmazandó megfelelőségértékelési eljárások, amelyeket a légierő-ezredes 1961-ben említett.
# 9                                                 15 ) a 2005/32/ec irányelv 8. cikkével összhangban ez a rendelet meghatározza a naptárt...
# ...                                                                                                                                      ...
# 830641  ( 9 ) a számítógépes eljárások használata fokozatosan helyettesíti a kis levet az adminisztratív tevékenységek különböző területein.
# 830643                                                  az előlegelszámoló tisztviselő a következők alapján és határain belül tehet kérdést:
# 830644                                                                                                Kezét mormolta, és bement az ebédlőbe.
# 830646                                                           Meg kell jegyezni, hogy ezek a piaci szegmensek valójában mit jelentenek...
# 830647                                                                                 Ez körülbelül a közösségi piac 60%-a egy jó fiúnak...
#
#                                                                                                                                  eng_translation  \
# 0                                      The Commission publishes this information in the C` series of the Official Journal of the European Union.
# 1                                              The Commission will communicate this information to the customs authorities of the Member States.
# 6                                           3 ) The Committee shall adopt the general rules for the interpretation of the Combined Nomenclature.
# 8                                                              But the calendar failed to indicate the applicable quality assessment procedures.
# 9                                     ( 15 ) This Regulation determines the date of sunset in accordance with Article 8 of Directive 2005/32/EC.
# ...                                                                                                                                          ...
# 830641                        ( 9 ) The use of computer procedures in the various areas of administrative activity gradually replaces your help.
# 830643  3 ) The imprest administrator shall do something on the basis of the following and for the third party entitled to the following limits:
# 830644                                                                   Tuppence murmured a contemptuous gesture and went into the dining room.
# 830646                                  It should be noted that these market segments represent this in terms of volume on the Community market.
# 830647                                                                                                                 It is 60 % of a good boy.
#
#         huen_similarity  enhu_similarity  hu_word_count  en_word_count
# 0              0.922374         0.777107           14.0           18.0
# 1              0.953655         0.897023            9.5           14.5
# 6              0.870230         0.760501           11.0           12.0
# 8              0.860972         0.806832           10.0           13.5
# 9              0.903163         0.959037           15.5           19.5
# ...                 ...              ...            ...            ...
# 830641         0.958414         0.925954           17.0           20.0
# 830643         0.928219         0.833042           16.0           20.0
# 830644         0.899864         0.802763            8.0           11.0
# 830646         0.943972         0.799594           13.5           16.0
# 830647         0.857901         0.698420            7.5           11.5
#
# [532875 rows x 8 columns]

# %%
df[(df['huen_similarity'] > huen_similarity_metrics['q0.01']) & (df['enhu_similarity'] > enhu_similarity_metrics['q0.01'])]
# Out:
#                                                                                                                                                hun  \
# 0                                                        A Bizottság ezt az információt az Európai Unió Hivatalos Lapja C sorozatában hirdeti ki .
# 1                                                                         A Bizottság ezeket az információkat közli a tagállamok vámhatóságaival .
# 2                                                                             Valamennyi módosító közlemény tartalmazza az útjait és a 16. mezőt .
# 3                                                                                         Az ember sohase találja el a 3. , a 7. , a 13. , a 14. .
# 4                                                                                          Végül a kulcs képe juttatott eszébe az itteni ügyeket .
# ...                                                                                                                                            ...
# 830643  ( 3 ) Az előlegelszámoló tisztviselő az alábbiak alapján és a következő határok között jogosult harmadik személy részére valamit végezni :
# 830644                                                                          Tuppence dünnyögött megvető kézmozdulatot , s bement az ebédlőbe .
# 830645                                                                                    U Po Kyin nemtetszése jeléül néhány udvarias szót tett .
# 830646                                    Megjegyzendő , hogy az említett piaci szegmensek mennyiségi szempontból a közösségi piac ezt teszik ki .
# 830647                                                                                                                Egy jó kisfiú 60%-át teszi .
#
#                                                                                                                   eng  \
# 0       the commission shall publish this information in the c series of the official journal of the european union .
# 1                 the commission shall communicate this information to the customs authorities of the member states .
# 2                                                                     all revision messages include the ways iv him .
# 3                                                            you can never guess field types 3 , 7 , 13 , 14 and 16 .
# 4                                                                                  the sight of the key reminded it .
# ...                                                                                                               ...
# 830643                          the imprest administrator may make a question on the basis and within the limits of :
# 830644                                                    tuppence murmured his hands and went into the dining room .
# 830645                                                           u po kyin threw up a few pleasant words in disgust .
# 830646                                 it should be noted that these market segments represent what in volume terms .
# 830647                                               thats around 60 % of the community market a good son has to do .
#
#                                                                                               hun_translation  \
# 0       a bizottság közzéteszi ezt az információt az európeai szakszervezet hivatalos lapjának c sorozatában.
# 1                                          a bizottság közli ezt az információt a tagállamok vámhatóságaival.
# 2                                                                           minden átmeneti üzenet benne van.
# 3                                                   A 3., 7., 13., 14. és 16. mezőtípust nem lehet kitalálni.
# 4                                                                            a kulcs látványa emlékeztette...
# ...                                                                                                       ...
# 830643                   az előlegelszámoló tisztviselő a következők alapján és határain belül tehet kérdést:
# 830644                                                                 Kezét mormolta, és bement az ebédlőbe.
# 830645                                                    u po kyin undorodva feldobott néhány kellemes szót.
# 830646                            Meg kell jegyezni, hogy ezek a piaci szegmensek valójában mit jelentenek...
# 830647                                                  Ez körülbelül a közösségi piac 60%-a egy jó fiúnak...
#
#                                                                                                                                  eng_translation  \
# 0                                      The Commission publishes this information in the C` series of the Official Journal of the European Union.
# 1                                              The Commission will communicate this information to the customs authorities of the Member States.
# 2                                                                                        Every revision message contains its paths and field 16.
# 3                                                                                                           One never finds it on 3, 7, 13, 14 .
# 4                                                                               Finally, a picture of the key reminded him of the business here.
# ...                                                                                                                                          ...
# 830643  3 ) The imprest administrator shall do something on the basis of the following and for the third party entitled to the following limits:
# 830644                                                                   Tuppence murmured a contemptuous gesture and went into the dining room.
# 830645                                                                                        U Po Kyin spoke a few polite words in displeasure.
# 830646                                  It should be noted that these market segments represent this in terms of volume on the Community market.
# 830647                                                                                                                 It is 60 % of a good boy.
#
#         huen_similarity  enhu_similarity  hu_word_count  en_word_count
# 0              0.922374         0.777107           14.0           18.0
# 1              0.953655         0.897023            9.5           14.5
# 2              0.734506         0.451700            8.0            9.0
# 3              0.804653         0.530200           14.0           13.0
# 4              0.883965         0.613354            7.0           10.0
# ...                 ...              ...            ...            ...
# 830643         0.928219         0.833042           16.0           20.0
# 830644         0.899864         0.802763            8.0           11.0
# 830645         0.783681         0.622425            9.0           11.0
# 830646         0.943972         0.799594           13.5           16.0
# 830647         0.857901         0.698420            7.5           11.5
#
# [814624 rows x 8 columns]

# %%
df['avg_huen_similarity'] = df['huen_similarity'] / df['en_word_count']
df['avg_enhu_similarity'] = df['enhu_similarity'] / df['hu_word_count']

# %%
sns.histplot(df['avg_huen_similarity'])
# Out:
# <AxesSubplot:xlabel='avg_huen_similarity', ylabel='Count'>

# %%
sns.histplot(df['avg_enhu_similarity'])
# Out:
# <AxesSubplot:xlabel='avg_enhu_similarity', ylabel='Count'>

# %%
avg_huen_similarity_metrics = get_basic_stats(df, 'avg_huen_similarity')
avg_huen_similarity_metrics
# Out:
# {'q0.001': 0.02408762652412881,
#  'q0.01': 0.031207912213058884,
#  'q0.25': 0.0605711693077568,
#  'q0.5': 0.0811218281586965,
#  'q0.75': 0.10662898123264312,
#  'q0.99': 0.18533366307379712,
#  'q0.999': 0.2202971870218019,
#  'min': -0.01778637742002805,
#  'max': 0.31222881873448693,
#  'mean': 0.08642062051945869,
#  'stdev': 0.03440046152194985}

# %%
avg_enhu_similarity_metrics = get_basic_stats(df, 'avg_enhu_similarity')
avg_enhu_similarity_metrics
# Out:
# {'q0.001': 0.023865377693666253,
#  'q0.01': 0.03308103836232965,
#  'q0.25': 0.06423805589261262,
#  'q0.5': 0.08420068025588989,
#  'q0.75': 0.10790213672823497,
#  'q0.99': 0.18015129660566648,
#  'q0.999': 0.21893046600478272,
#  'min': -0.0703383982181549,
#  'max': 0.3160068194071452,
#  'mean': 0.08838038967418456,
#  'stdev': 0.03252474023687921}

# %%
df[df['avg_enhu_similarity'] > 0.05]
# Out:
#                                                                                                                                                hun  \
# 0                                                        A Bizottság ezt az információt az Európai Unió Hivatalos Lapja C sorozatában hirdeti ki .
# 1                                                                         A Bizottság ezeket az információkat közli a tagállamok vámhatóságaival .
# 2                                                                             Valamennyi módosító közlemény tartalmazza az útjait és a 16. mezőt .
# 4                                                                                          Végül a kulcs képe juttatott eszébe az itteni ügyeket .
# 5                                                                                                   Rendben van , John , mindent majd én intézem .
# ...                                                                                                                                            ...
# 830643  ( 3 ) Az előlegelszámoló tisztviselő az alábbiak alapján és a következő határok között jogosult harmadik személy részére valamit végezni :
# 830644                                                                          Tuppence dünnyögött megvető kézmozdulatot , s bement az ebédlőbe .
# 830645                                                                                    U Po Kyin nemtetszése jeléül néhány udvarias szót tett .
# 830646                                    Megjegyzendő , hogy az említett piaci szegmensek mennyiségi szempontból a közösségi piac ezt teszik ki .
# 830647                                                                                                                Egy jó kisfiú 60%-át teszi .
#
#                                                                                                                   eng  \
# 0       the commission shall publish this information in the c series of the official journal of the european union .
# 1                 the commission shall communicate this information to the customs authorities of the member states .
# 2                                                                     all revision messages include the ways iv him .
# 4                                                                                  the sight of the key reminded it .
# 5                                                                     all right , john , ill handle her at this end .
# ...                                                                                                               ...
# 830643                          the imprest administrator may make a question on the basis and within the limits of :
# 830644                                                    tuppence murmured his hands and went into the dining room .
# 830645                                                           u po kyin threw up a few pleasant words in disgust .
# 830646                                 it should be noted that these market segments represent what in volume terms .
# 830647                                               thats around 60 % of the community market a good son has to do .
#
#                                                                                               hun_translation  \
# 0       a bizottság közzéteszi ezt az információt az európeai szakszervezet hivatalos lapjának c sorozatában.
# 1                                          a bizottság közli ezt az információt a tagállamok vámhatóságaival.
# 2                                                                           minden átmeneti üzenet benne van.
# 4                                                                            a kulcs látványa emlékeztette...
# 5                                                          Rendben van, John, ennek a végén majd elintézem...
# ...                                                                                                       ...
# 830643                   az előlegelszámoló tisztviselő a következők alapján és határain belül tehet kérdést:
# 830644                                                                 Kezét mormolta, és bement az ebédlőbe.
# 830645                                                    u po kyin undorodva feldobott néhány kellemes szót.
# 830646                            Meg kell jegyezni, hogy ezek a piaci szegmensek valójában mit jelentenek...
# 830647                                                  Ez körülbelül a közösségi piac 60%-a egy jó fiúnak...
#
#                                                                                                                                  eng_translation  \
# 0                                      The Commission publishes this information in the C` series of the Official Journal of the European Union.
# 1                                              The Commission will communicate this information to the customs authorities of the Member States.
# 2                                                                                        Every revision message contains its paths and field 16.
# 4                                                                               Finally, a picture of the key reminded him of the business here.
# 5                                                                                                        All right, John, Ill handle everything.
# ...                                                                                                                                          ...
# 830643  3 ) The imprest administrator shall do something on the basis of the following and for the third party entitled to the following limits:
# 830644                                                                   Tuppence murmured a contemptuous gesture and went into the dining room.
# 830645                                                                                        U Po Kyin spoke a few polite words in displeasure.
# 830646                                  It should be noted that these market segments represent this in terms of volume on the Community market.
# 830647                                                                                                                 It is 60 % of a good boy.
#
#         huen_similarity  enhu_similarity  hu_word_count  en_word_count  \
# 0              0.922374         0.777107           14.0           18.0
# 1              0.953655         0.897023            9.5           14.5
# 2              0.734506         0.451700            8.0            9.0
# 4              0.883965         0.613354            7.0           10.0
# 5              0.570700         0.658716            9.0            9.0
# ...                 ...              ...            ...            ...
# 830643         0.928219         0.833042           16.0           20.0
# 830644         0.899864         0.802763            8.0           11.0
# 830645         0.783681         0.622425            9.0           11.0
# 830646         0.943972         0.799594           13.5           16.0
# 830647         0.857901         0.698420            7.5           11.5
#
#         avg_huen_similarity  avg_enhu_similarity
# 0                  0.051243             0.055508
# 1                  0.065769             0.094424
# 2                  0.081612             0.056463
# 4                  0.088397             0.087622
# 5                  0.063411             0.073191
# ...                     ...                  ...
# 830643             0.046411             0.052065
# 830644             0.081806             0.100345
# 830645             0.071244             0.069158
# 830646             0.058998             0.059229
# 830647             0.074600             0.093123
#
# [747168 rows x 10 columns]
