# %%
import yaml
import torch.nn as nn
from collections import defaultdict, Counter
import onmt
from onmt.inputters.inputter import (
    _load_vocab,
    _build_fields_vocab,
    get_fields,
    IterOnDevice,
)
from onmt.inputters.corpus import ParallelCorpus
from onmt.inputters.dynamic_iterator import DynamicDatasetIter
from onmt.utils.misc import set_random_seed
from onmt.utils.parse import ArgumentParser
from onmt.opts import dynamic_prepare_opts
from transformers import AutoTokenizer
import torch

from onmt.utils.logging import init_logger, logger

from bert.models import BertEncoder
from bert.transforms import BertTransform

# %%
parser = ArgumentParser()
onmt.opts.train_opts(parser)

# %%
base_args = ["-config", "../opennmt/experiments-bert/runs/bert/config.yaml"]
opts, unknown = parser.parse_known_args(base_args)

# %%
init_logger(log_file=opts.log_file)

is_cuda = torch.cuda.is_available()
set_random_seed(opts.seed, is_cuda)

# build_vocab_main(opts)

src_vocab_path = opts.src_vocab
tgt_vocab_path = opts.tgt_vocab

counters = defaultdict(Counter)
eng_tokenizer = AutoTokenizer.from_pretrained("bert-base-cased")

_src_vocab = [[k, v] for k, v in eng_tokenizer.get_vocab().items()]
_src_vocab_size = len(_src_vocab)
for k, _ in _src_vocab:
    counters["src"][k] = 1000  # Set dummy count

# load target vocab
_tgt_vocab, _tgt_vocab_size = _load_vocab(tgt_vocab_path, "tgt", counters)

# initialize fields
src_nfeats, tgt_nfeats = 0, 0  # do not support word features for now
fields = get_fields("text", src_nfeats, tgt_nfeats)

share_vocab = False
vocab_size_multiple = 1
src_vocab_size = _src_vocab_size
tgt_vocab_size = opts.tgt_vocab_size
src_words_min_frequency = 0
tgt_words_min_frequency = opts.tgt_words_min_frequency

vocab_fields = _build_fields_vocab(
    fields,
    counters,
    "text",
    share_vocab,
    vocab_size_multiple,
    src_vocab_size,
    src_words_min_frequency,
    tgt_vocab_size,
    tgt_words_min_frequency,
)

# src_text_field = vocab_fields["src"].base_field
# src_vocab = src_text_field.vocab
# src_padding = src_vocab.stoi[src_text_field.pad_token]

tgt_text_field = vocab_fields["tgt"].base_field
tgt_vocab = tgt_text_field.vocab
tgt_padding = tgt_vocab.stoi[tgt_text_field.pad_token]
# Out:
# [2021-10-19 14:18:52,168 INFO] Loading tgt vocabulary from /home/bana/Code/hu-nmt/opennmt/experiments-bert/vocabs/vocab.hu
# [2021-10-19 14:18:52,169 INFO] Loaded tgt vocab has 32 tokens.
# [2021-10-19 14:18:52,172 INFO]  * tgt vocab size: 36.
# [2021-10-19 14:18:52,213 INFO]  * src vocab size: 28998.

# %%
encoder = BertEncoder()
decoder_embeddings = onmt.modules.Embeddings(
    opts.tgt_word_vec_size, len(tgt_vocab), word_padding_idx=tgt_padding
)
decoder = onmt.decoders.transformer.TransformerDecoder.from_opt(
    opts, decoder_embeddings
)

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
model = onmt.models.model.NMTModel(encoder, decoder)
model.to(device)

logger.info(model)
model.count_parameters(log=logger.info)
# Out:
# [2021-10-19 14:18:59,128 INFO] NMTModel(
#   (encoder): BertEncoder(
#     (base): BertModel(
#       (embeddings): BertEmbeddings(
#         (word_embeddings): Embedding(28996, 768, padding_idx=0)
#         (position_embeddings): Embedding(512, 768)
#         (token_type_embeddings): Embedding(2, 768)
#         (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (encoder): BertEncoder(
#         (layer): ModuleList(
#           (0): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (1): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (2): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (3): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (4): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (5): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (6): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (7): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (8): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (9): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (10): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (11): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#       )
#       (pooler): BertPooler(
#         (dense): Linear(in_features=768, out_features=768, bias=True)
#         (activation): Tanh()
#       )
#     )
#   )
#   (decoder): TransformerDecoder(
#     (embeddings): Embeddings(
#       (make_embedding): Sequential(
#         (emb_luts): Elementwise(
#           (0): Embedding(36, 512, padding_idx=1)
#         )
#       )
#     )
#     (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#     (transformer_layers): ModuleList(
#       (0): TransformerDecoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=True)
#           (linear_values): Linear(in_features=512, out_features=512, bias=True)
#           (linear_query): Linear(in_features=512, out_features=512, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=512, out_features=2048, bias=True)
#           (w_2): Linear(in_features=2048, out_features=512, bias=True)
#           (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (dropout_1): Dropout(p=0.1, inplace=False)
#           (dropout_2): Dropout(p=0.1, inplace=False)
#         )
#         (layer_norm_1): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#         (drop): Dropout(p=0.1, inplace=False)
#         (context_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=True)
#           (linear_values): Linear(in_features=512, out_features=512, bias=True)
#           (linear_query): Linear(in_features=512, out_features=512, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (layer_norm_2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       )
#       (1): TransformerDecoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=True)
#           (linear_values): Linear(in_features=512, out_features=512, bias=True)
#           (linear_query): Linear(in_features=512, out_features=512, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=512, out_features=2048, bias=True)
#           (w_2): Linear(in_features=2048, out_features=512, bias=True)
#           (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (dropout_1): Dropout(p=0.1, inplace=False)
#           (dropout_2): Dropout(p=0.1, inplace=False)
#         )
#         (layer_norm_1): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#         (drop): Dropout(p=0.1, inplace=False)
#         (context_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=True)
#           (linear_values): Linear(in_features=512, out_features=512, bias=True)
#           (linear_query): Linear(in_features=512, out_features=512, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (layer_norm_2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       )
#       (2): TransformerDecoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=True)
#           (linear_values): Linear(in_features=512, out_features=512, bias=True)
#           (linear_query): Linear(in_features=512, out_features=512, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=512, out_features=2048, bias=True)
#           (w_2): Linear(in_features=2048, out_features=512, bias=True)
#           (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (dropout_1): Dropout(p=0.1, inplace=False)
#           (dropout_2): Dropout(p=0.1, inplace=False)
#         )
#         (layer_norm_1): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#         (drop): Dropout(p=0.1, inplace=False)
#         (context_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=True)
#           (linear_values): Linear(in_features=512, out_features=512, bias=True)
#           (linear_query): Linear(in_features=512, out_features=512, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (layer_norm_2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       )
#       (3): TransformerDecoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=True)
#           (linear_values): Linear(in_features=512, out_features=512, bias=True)
#           (linear_query): Linear(in_features=512, out_features=512, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=512, out_features=2048, bias=True)
#           (w_2): Linear(in_features=2048, out_features=512, bias=True)
#           (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (dropout_1): Dropout(p=0.1, inplace=False)
#           (dropout_2): Dropout(p=0.1, inplace=False)
#         )
#         (layer_norm_1): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#         (drop): Dropout(p=0.1, inplace=False)
#         (context_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=True)
#           (linear_values): Linear(in_features=512, out_features=512, bias=True)
#           (linear_query): Linear(in_features=512, out_features=512, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (layer_norm_2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       )
#     )
#   )
# )
# [2021-10-19 14:18:59,137 INFO] encoder: 108310272
# [2021-10-19 14:18:59,138 INFO] decoder: 16835584
# [2021-10-19 14:18:59,139 INFO] * number of parameters: 125145856
# (108310272, 16835584)

# %%
# Specify the tgt word generator and loss computation module
model.generator = nn.Sequential(
    nn.Linear(opts.dec_rnn_size, len(tgt_vocab)), nn.LogSoftmax(dim=-1)
).to(device)

optimizer = onmt.utils.optimizers.Optimizer.from_opt(model, opts)

# %%
data_config = yaml.load(opts.data)
opts.data = data_config
src_train = data_config["corpus"]["path_src"]
tgt_train = data_config["corpus"]["path_tgt"]
src_val = data_config["valid"]["path_src"]
tgt_val = data_config["valid"]["path_tgt"]

# build the ParallelCorpus
corpus = ParallelCorpus("corpus", src_train, tgt_train)
valid = ParallelCorpus("valid", src_val, tgt_val)

bertTransform = BertTransform(opts, src_tokenizer=eng_tokenizer)
bertTransform.warm_up()

gpu_rank = 0 if is_cuda else -1  # TODO: read from config
# Out:
# /tmp/ipykernel_39351/2022652398.py:1: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data_config = yaml.load(opts.data)

# %%
train_iter = DynamicDatasetIter.from_opts(
    corpora={"corpus": corpus},
    transforms={"berttokenizer": bertTransform},
    fields=vocab_fields,
    opts=opts,
    is_train=True,
)
train_iter = iter(IterOnDevice(train_iter, gpu_rank))
valid_iter = DynamicDatasetIter.from_opts(
    corpora={"valid": valid},
    transforms={"berttokenizer": bertTransform},
    fields=vocab_fields,
    opts=opts,
    is_train=False,
)
valid_iter = IterOnDevice(valid_iter, gpu_rank)

report_manager = onmt.utils.build_report_manager(opts, gpu_rank)
model_saver = onmt.models.build_model_saver(
    model_opt=opts, opt=opts, model=model, fields=fields, optim=optimizer
)

trainer = onmt.trainer.build_trainer(
    opts,
    device_id=gpu_rank,
    model=model,
    fields=fields,
    optim=optimizer,
    model_saver=model_saver,
)
# Out:
# 2021-10-19 14:18:59.747479: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-10-19 14:18:59.747508: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
trainer.train(
    train_iter=train_iter,
    train_steps=opts.train_steps,
    valid_iter=valid_iter,
    valid_steps=opts.valid_steps,
    save_checkpoint_steps=opts.save_checkpoint_steps,
)
# Out:
# [2021-10-19 14:19:01,042 INFO] Start training loop and validate every 10000 steps...
# [2021-10-19 14:19:01,043 INFO] corpus's transforms: TransformPipe(BertTransform(share_vocab=False, src_subword_model=/home/bana/Code/hu-nmt/opennmt/experiments-bert/sp_models/bpe_en.model, tgt_subword_model=/home/bana/Code/hu-nmt/opennmt/experiments-bert/sp_models/bpe_hu.model, src_subword_alpha=0.0, tgt_subword_alpha=0.0, src_subword_vocab=, tgt_subword_vocab=, src_vocab_threshold=0, tgt_vocab_threshold=0, src_subword_nbest=1, tgt_subword_nbest=1))
# [2021-10-19 14:19:01,044 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,045 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,046 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,047 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,048 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,049 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,050 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,051 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,052 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,053 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,054 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,055 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,056 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,057 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,058 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,059 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,060 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,061 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,062 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,062 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,063 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,064 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,065 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,065 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,066 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,067 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,068 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,069 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,070 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,070 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,071 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,072 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,073 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,074 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,075 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,075 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,076 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,077 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,078 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,078 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,079 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,080 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,081 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,082 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,083 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,083 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,084 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,085 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,086 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,087 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,087 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,088 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,089 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,090 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,091 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,092 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,094 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,095 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,096 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,097 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,098 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,100 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,101 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,102 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,103 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,104 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,105 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,106 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,107 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,107 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,108 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,109 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,110 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,111 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,112 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,113 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,114 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,115 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,116 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,117 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,118 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,119 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,120 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,122 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,125 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,129 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,131 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,139 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,142 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,143 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,144 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,145 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,146 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,147 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,148 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,149 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,150 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,152 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,152 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,153 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,154 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,156 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,157 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,159 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,160 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,161 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,162 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,163 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,165 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,166 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,167 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,168 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,169 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,170 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,172 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,173 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,174 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,176 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,177 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,179 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,180 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,181 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,182 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,183 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,184 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,185 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,186 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,187 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,189 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,190 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,192 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,193 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,195 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,196 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,198 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,199 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,200 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,201 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,202 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,204 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,205 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,206 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,207 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,208 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,210 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,211 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,212 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,214 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,215 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,216 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,217 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,219 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,220 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,221 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,222 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,223 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,224 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,225 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,226 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,227 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,228 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,229 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,230 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,231 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,233 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,234 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,235 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,236 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,237 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,238 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,239 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,240 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,241 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,242 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,245 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,246 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,248 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,249 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,250 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,251 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,252 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,253 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,255 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,256 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,257 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,262 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,264 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,265 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,266 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,267 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,268 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,269 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,270 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,270 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,271 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,272 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,273 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,274 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,275 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,276 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,276 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,278 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,279 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,280 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,282 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,283 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,284 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,286 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,287 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,290 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,291 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,292 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,293 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,295 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,296 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,297 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,298 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,299 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,300 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,301 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,302 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,303 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,304 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,305 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,306 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,307 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,308 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,315 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,319 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,320 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,321 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,322 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,323 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,325 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,327 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,328 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,331 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,333 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,334 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,335 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,337 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,338 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,339 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,340 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,341 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,343 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,344 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,345 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,346 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,349 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,351 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,352 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,353 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,354 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,355 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,357 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,359 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,372 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,380 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,381 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,382 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,384 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,385 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,386 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# [2021-10-19 14:19:01,388 INFO] Loading ParallelCorpus(/home/bana/Data/combined-tiny/hunglish2-tiny-train.en, /home/bana/Data/combined-tiny/hunglish2-tiny-train.hu, align=None)...
# ...
# [2021-10-19 14:19:03,345 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,345 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,346 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,350 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,353 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,358 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,359 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,359 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,360 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,361 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,361 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,362 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,362 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,363 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,363 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,365 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,366 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,367 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,367 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,368 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,369 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,370 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,371 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,372 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,372 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,373 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,373 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,374 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,375 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,376 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,376 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,377 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,378 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,378 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,379 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,380 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,383 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,384 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,385 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,385 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,387 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,387 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,388 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,389 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,390 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,390 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,391 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,392 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,393 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,393 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,394 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,395 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,395 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,396 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,397 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,398 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,401 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,403 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,403 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,404 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,405 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,406 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,406 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,407 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,407 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,408 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,409 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,409 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,410 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,413 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,413 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,414 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,415 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,415 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,416 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,417 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,417 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,418 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,418 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,419 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,419 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,420 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,421 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,421 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,422 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,422 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,426 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,427 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,427 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,428 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,428 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,429 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,429 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,430 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,431 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,431 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,431 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,432 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# [2021-10-19 14:19:03,432 WARNING] The batch will be filled until we reach 8,its size may exceed 2 tokens
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_39351/2314428943.py in <module>
# ----> 1 trainer.train(
#       2     train_iter=train_iter,
#       3     train_steps=opts.train_steps,
#       4     valid_iter=valid_iter,
#       5     valid_steps=opts.valid_steps,
#
# ~/miniconda3/envs/hu-nmt/lib/python3.8/site-packages/onmt/trainer.py in train(self, train_iter, train_steps, save_checkpoint_steps, valid_iter, valid_steps)
#     240                                     (normalization))
#     241
# --> 242             self._gradient_accumulation(
#     243                 batches, normalization, total_stats,
#     244                 report_stats)
#
# ~/miniconda3/envs/hu-nmt/lib/python3.8/site-packages/onmt/trainer.py in _gradient_accumulation(self, true_batches, normalization, total_stats, report_stats)
#     364
#     365                 with torch.cuda.amp.autocast(enabled=self.optim.amp):
# --> 366                     outputs, attns = self.model(
#     367                         src, tgt, src_lengths, bptt=bptt,
#     368                         with_align=self.with_align)
#
# ~/miniconda3/envs/hu-nmt/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# ~/miniconda3/envs/hu-nmt/lib/python3.8/site-packages/onmt/models/model.py in forward(self, src, tgt, lengths, bptt, with_align)
#      65         if not bptt:
#      66             self.decoder.init_state(src, memory_bank, enc_state)
# ---> 67         dec_out, attns = self.decoder(dec_in, memory_bank,
#      68                                       memory_lengths=lengths,
#      69                                       with_align=with_align)
#
# ~/miniconda3/envs/hu-nmt/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# ~/miniconda3/envs/hu-nmt/lib/python3.8/site-packages/onmt/decoders/transformer.py in forward(self, tgt, memory_bank, step, **kwargs)
#     464                 else None
#     465             )
# --> 466             output, attn, attn_align = layer(
#     467                 output,
#     468                 src_memory_bank,
#
# ~/miniconda3/envs/hu-nmt/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# ~/miniconda3/envs/hu-nmt/lib/python3.8/site-packages/onmt/decoders/transformer.py in forward(self, *args, **kwargs)
#      96         """
#      97         with_align = kwargs.pop("with_align", False)
# ---> 98         output, attns = self._forward(*args, **kwargs)
#      99         top_attn = attns[:, 0, :, :].contiguous()
#     100         attn_align = None
#
# ~/miniconda3/envs/hu-nmt/lib/python3.8/site-packages/onmt/decoders/transformer.py in _forward(self, inputs, memory_bank, src_pad_mask, tgt_pad_mask, layer_cache, step, future)
#     267
#     268         query_norm = self.layer_norm_2(query)
# --> 269         mid, attns = self.context_attn(
#     270             memory_bank,
#     271             memory_bank,
#
# ~/miniconda3/envs/hu-nmt/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# ~/miniconda3/envs/hu-nmt/lib/python3.8/site-packages/onmt/modules/multi_headed_attn.py in forward(self, key, value, query, mask, layer_cache, attn_type)
#     160                 layer_cache["memory_values"] = value
#     161         else:
# --> 162             key = self.linear_keys(key)
#     163             value = self.linear_values(value)
#     164             query = self.linear_query(query)
#
# ~/miniconda3/envs/hu-nmt/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# ~/miniconda3/envs/hu-nmt/lib/python3.8/site-packages/torch/nn/modules/linear.py in forward(self, input)
#      89
#      90     def forward(self, input: Tensor) -> Tensor:
# ---> 91         return F.linear(input, self.weight, self.bias)
#      92
#      93     def extra_repr(self) -> str:
#
# ~/miniconda3/envs/hu-nmt/lib/python3.8/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1674         ret = torch.addmm(bias, input, weight.t())
#    1675     else:
# -> 1676         output = input.matmul(weight.t())
#    1677         if bias is not None:
#    1678             output += bias
#
# RuntimeError: mat1 dim 1 must match mat2 dim 0

# %%
opts
# Out:
# Namespace(aan_useffn=False, accum_count=[1], accum_steps=[0], adagrad_accumulator_init=0, adam_beta1=0.9, adam_beta2=0.998, alignment_heads=0, alignment_layer=-3, apex_opt_level='O1', attention_dropout=[0.1], average_decay=0.0005, average_every=1, batch_size=2, batch_size_multiple=None, batch_type='sents', bidir_edges=True, both_embeddings=None, bridge=False, bridge_extra_node=True, brnn=None, bucket_size=2048, cnn_kernel_width=3, config='../opennmt/experiments-bert/runs/bert/config.yaml', context_gate=None, copy_attn=False, copy_attn_force=False, copy_attn_type=None, copy_loss_by_seqlength=False, coverage_attn=False, data={'corpus': {'path_src': '/home/bana/Data/combined-tiny/hunglish2-tiny-train.en', 'path_tgt': '/home/bana/Data/combined-tiny/hunglish2-tiny-train.hu', 'weight': 1, 'transforms': ['berttokenizer']}, 'valid': {'path_src': '/home/bana/Data/combined-tiny/hunglish2-tiny-valid.en', 'path_tgt': '/home/bana/Data/combined-tiny/hunglish2-tiny-valid.hu', 'weight': 1, 'transforms': ['berttokenizer']}}, data_type='text', dec_layers=4, dec_rnn_size=512, decay_method='noam', decay_steps=10000, decoder_type='transformer', dropout=[0.1], dropout_steps=[0], dump_fields=False, dump_transforms=False, early_stopping=5, early_stopping_criteria=['ppl'], embeddings_type=None, enc_layers=4, enc_rnn_size=500, encoder_type='transformer', epochs=0, exp='', exp_host='', feat_merge='concat', feat_vec_exponent=0.7, feat_vec_size=-1, freeze_word_vecs_dec=False, freeze_word_vecs_enc=False, full_context_alignment=False, generator_function='softmax', global_attention='general', global_attention_function='softmax', gpu_backend='nccl', gpu_ranks=[0], gpu_verbose_level=0, gpuid=[], heads=8, input_feed=1, insert_ratio=0.0, keep_checkpoint=10, label_smoothing=0.1, lambda_align=0.0, lambda_coverage=0.0, layers=-1, learning_rate=2.0, learning_rate_decay=0.5, log_file='/home/bana/Code/hu-nmt/opennmt/experiments-bert/runs/bert/logs', log_file_level='0', loss_scale=0, mask_length='subword', mask_ratio=0.0, master_ip='localhost', master_port=10000, max_generator_batches=32, max_grad_norm=0.0, max_relative_positions=0, model_dtype='fp16', model_task='seq2seq', model_type='text', n_edge_types=2, n_node=2, n_sample=0, n_steps=2, normalization='tokens', optim='adam', overwrite=False, param_init=0.0, param_init_glorot=True, permute_sent_ratio=0.0, poisson_lambda=3.0, pool_factor=8192, pos_ffn_activation_fn='relu', position_encoding=False, pre_word_vecs_dec=None, pre_word_vecs_enc=None, queue_size=40, random_ratio=0.0, replace_length=-1, report_every=100, reset_optim='keep_states', reuse_copy_attn=False, rnn_size=512, rnn_type='LSTM', rotate_ratio=0.0, save_checkpoint_steps=10000, save_config=None, save_data='/home/bana/Code/hu-nmt/opennmt/experiments-bert/runs/bert/samples', save_model='/home/bana/Code/hu-nmt/opennmt/experiments-bert/runs/bert/model', seed=1234, self_attn_type='scaled-dot', share_decoder_embeddings=False, share_embeddings=False, share_vocab=False, single_pass=False, skip_empty_level='warning', src_embeddings=None, src_ggnn_size=0, src_onmttok_kwargs="{'mode': 'none'}", src_seq_length=16, src_seq_length_trunc=None, src_subword_alpha=0.0, src_subword_model='/home/bana/Code/hu-nmt/opennmt/experiments-bert/sp_models/bpe_en.model', src_subword_nbest=1, src_subword_type='none', src_subword_vocab='', src_vocab='/home/bana/Code/hu-nmt/opennmt/experiments-bert/vocabs/vocab.en', src_vocab_size=20000, src_vocab_threshold=0, src_word_vec_size=500, src_words_min_frequency=0, start_decay_steps=50000, state_dim=512, switchout_temperature=1.0, tensorboard=True, tensorboard_log_dir='/home/bana/Code/hu-nmt/opennmt/experiments-bert/runs/bert/tensorboard', tensorboard_log_dir_dated='/home/bana/Code/hu-nmt/opennmt/experiments-bert/runs/bert/tensorboard/Oct-19_14-10-13', tgt_embeddings=None, tgt_onmttok_kwargs="{'mode': 'none'}", tgt_seq_length=16, tgt_seq_length_trunc=None, tgt_subword_alpha=0.0, tgt_subword_model='/home/bana/Code/hu-nmt/opennmt/experiments-bert/ ...
