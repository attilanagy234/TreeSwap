# %%
from transformers import MarianMTModel, MarianTokenizer

# %%
import torch
import transformers

# %%
torch.version.cuda
# Out:
# '10.2'

# %%
print(torch.cuda.device_count())   # --> 0
print(torch.cuda.is_available())   # --> False
print(torch.version.cuda)          # --> 9.0.176
# Out:
# 0
# False
# 10.2

# %%
transformers.is_torch_available()
# Out:
# True

# %%
import numpy as np

# %%
def download(model_name):
    tokenizer = MarianTokenizer.from_pretrained(model_name)
    model = MarianMTModel.from_pretrained(model_name)
    return tokenizer, model

# %%
# download model for English -> Romance
trg_lang_tokenizer, trg_lang_model = download('Helsinki-NLP/opus-mt-en-ROMANCE')
# download model for Romance -> English
src_lang_tokenizer, src_lang_model = download('Helsinki-NLP/opus-mt-ROMANCE-en')

# %%
dir(trg_lang_model)
# Out:
# ['T_destination',
#  '__annotations__',
#  '__call__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_apply',
#  '_backward_hooks',
#  '_buffers',
#  '_call_impl',
#  '_convert_head_mask_to_5d',
#  '_expand_inputs_for_generation',
#  '_force_token_id_to_be_generated',
#  '_forward_hooks',
#  '_forward_pre_hooks',
#  '_forward_unimplemented',
#  '_get_decoder_start_token_id',
#  '_get_logits_processor',
#  '_get_logits_warper',
#  '_get_name',
#  '_get_pad_token_id',
#  '_get_resized_embeddings',
#  '_get_resized_lm_head',
#  '_hook_rss_memory_post_forward',
#  '_hook_rss_memory_pre_forward',
#  '_init_sequence_length_for_generation',
#  '_init_weights',
#  '_keys_to_ignore_on_load_missing',
#  '_keys_to_ignore_on_load_unexpected',
#  '_keys_to_ignore_on_save',
#  '_load_from_state_dict',
#  '_load_state_dict_pre_hooks',
#  '_modules',
#  '_named_members',
#  '_non_persistent_buffers_set',
#  '_parameters',
#  '_prepare_attention_mask_for_generation',
#  '_prepare_decoder_input_ids_for_generation',
#  '_prepare_encoder_decoder_kwargs_for_generation',
#  '_prepare_input_ids_for_generation',
#  '_register_load_state_dict_pre_hook',
#  '_register_state_dict_hook',
#  '_reorder_cache',
#  '_replicate_for_data_parallel',
#  '_resize_final_logits_bias',
#  '_resize_token_embeddings',
#  '_save_to_state_dict',
#  '_slow_forward',
#  '_state_dict_hooks',
#  '_tie_encoder_decoder_weights',
#  '_tie_or_clone_weights',
#  '_update_model_kwargs_for_generation',
#  '_update_seq_length_for_generation',
#  '_version',
#  'add_memory_hooks',
#  'add_module',
#  'adjust_logits_during_generation',
#  'apply',
#  'base_model',
#  'base_model_prefix',
#  'beam_sample',
#  'beam_search',
#  'bfloat16',
#  'buffers',
#  'children',
#  'config',
#  'config_class',
#  'cpu',
#  'cuda',
#  'device',
#  'double',
#  'dtype',
#  'dummy_inputs',
#  'dump_patches',
#  'estimate_tokens',
#  'eval',
#  'extra_repr',
#  'final_logits_bias',
#  'float',
#  'floating_point_ops',
#  'forward',
#  'from_pretrained',
#  'generate',
#  'get_decoder',
#  'get_encoder',
#  'get_extended_attention_mask',
#  'get_head_mask',
#  'get_input_embeddings',
#  'get_output_embeddings',
#  'greedy_search',
#  'group_beam_search',
#  'half',
#  'init_weights',
#  'invert_attention_mask',
#  'is_parallelizable',
#  'lm_head',
#  'load_state_dict',
#  'model',
#  'modules',
#  'name_or_path',
#  'named_buffers',
#  'named_children',
#  'named_modules',
#  'named_parameters',
#  'num_parameters',
#  'parameters',
#  'prepare_inputs_for_generation',
#  'prune_heads',
#  'register_backward_hook',
#  'register_buffer',
#  'register_forward_hook',
#  'register_forward_pre_hook',
#  'register_parameter',
#  'requires_grad_',
#  'reset_memory_hooks_state',
#  'resize_token_embeddings',
#  'sample',
#  'save_pretrained',
#  'set_input_embeddings',
#  'set_output_embeddings',
#  'share_memory',
#  'state_dict',
#  'tie_weights',
#  'to',
#  'train',
#  'training',
#  'type',
#  'zero_grad']

# %%
dir(MarianMTModel)
# Out:
# ['T_destination',
#  '__annotations__',
#  '__call__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_apply',
#  '_call_impl',
#  '_convert_head_mask_to_5d',
#  '_expand_inputs_for_generation',
#  '_force_token_id_to_be_generated',
#  '_forward_unimplemented',
#  '_get_decoder_start_token_id',
#  '_get_logits_processor',
#  '_get_logits_warper',
#  '_get_name',
#  '_get_pad_token_id',
#  '_get_resized_embeddings',
#  '_get_resized_lm_head',
#  '_hook_rss_memory_post_forward',
#  '_hook_rss_memory_pre_forward',
#  '_init_sequence_length_for_generation',
#  '_init_weights',
#  '_keys_to_ignore_on_load_missing',
#  '_keys_to_ignore_on_load_unexpected',
#  '_keys_to_ignore_on_save',
#  '_load_from_state_dict',
#  '_named_members',
#  '_prepare_attention_mask_for_generation',
#  '_prepare_decoder_input_ids_for_generation',
#  '_prepare_encoder_decoder_kwargs_for_generation',
#  '_prepare_input_ids_for_generation',
#  '_register_load_state_dict_pre_hook',
#  '_register_state_dict_hook',
#  '_reorder_cache',
#  '_replicate_for_data_parallel',
#  '_resize_final_logits_bias',
#  '_resize_token_embeddings',
#  '_save_to_state_dict',
#  '_slow_forward',
#  '_tie_encoder_decoder_weights',
#  '_tie_or_clone_weights',
#  '_update_model_kwargs_for_generation',
#  '_update_seq_length_for_generation',
#  '_version',
#  'add_memory_hooks',
#  'add_module',
#  'adjust_logits_during_generation',
#  'apply',
#  'base_model',
#  'base_model_prefix',
#  'beam_sample',
#  'beam_search',
#  'bfloat16',
#  'buffers',
#  'children',
#  'config_class',
#  'cpu',
#  'cuda',
#  'device',
#  'double',
#  'dtype',
#  'dummy_inputs',
#  'dump_patches',
#  'estimate_tokens',
#  'eval',
#  'extra_repr',
#  'float',
#  'floating_point_ops',
#  'forward',
#  'from_pretrained',
#  'generate',
#  'get_decoder',
#  'get_encoder',
#  'get_extended_attention_mask',
#  'get_head_mask',
#  'get_input_embeddings',
#  'get_output_embeddings',
#  'greedy_search',
#  'group_beam_search',
#  'half',
#  'init_weights',
#  'invert_attention_mask',
#  'is_parallelizable',
#  'load_state_dict',
#  'modules',
#  'named_buffers',
#  'named_children',
#  'named_modules',
#  'named_parameters',
#  'num_parameters',
#  'parameters',
#  'prepare_inputs_for_generation',
#  'prune_heads',
#  'register_backward_hook',
#  'register_buffer',
#  'register_forward_hook',
#  'register_forward_pre_hook',
#  'register_parameter',
#  'requires_grad_',
#  'reset_memory_hooks_state',
#  'resize_token_embeddings',
#  'sample',
#  'save_pretrained',
#  'set_input_embeddings',
#  'set_output_embeddings',
#  'share_memory',
#  'state_dict',
#  'tie_weights',
#  'to',
#  'train',
#  'type',
#  'zero_grad']

# %%
trg_lang_model.cuda()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-20-d56eb9856cf7> in <module>
# ----> 1 trg_lang_model.cuda()
#
# ~/miniconda3/envs/nmt38/lib/python3.8/site-packages/torch/nn/modules/module.py in cuda(self, device)
#     456             Module: self
#     457         """
# --> 458         return self._apply(lambda t: t.cuda(device))
#     459
#     460     def cpu(self: T) -> T:
#
# ~/miniconda3/envs/nmt38/lib/python3.8/site-packages/torch/nn/modules/module.py in _apply(self, fn)
#     352     def _apply(self, fn):
#     353         for module in self.children():
# --> 354             module._apply(fn)
#     355
#     356         def compute_should_use_set_data(tensor, tensor_applied):
#
# ~/miniconda3/envs/nmt38/lib/python3.8/site-packages/torch/nn/modules/module.py in _apply(self, fn)
#     352     def _apply(self, fn):
#     353         for module in self.children():
# --> 354             module._apply(fn)
#     355
#     356         def compute_should_use_set_data(tensor, tensor_applied):
#
# ~/miniconda3/envs/nmt38/lib/python3.8/site-packages/torch/nn/modules/module.py in _apply(self, fn)
#     374                 # `with torch.no_grad():`
#     375                 with torch.no_grad():
# --> 376                     param_applied = fn(param)
#     377                 should_use_set_data = compute_should_use_set_data(param, param_applied)
#     378                 if should_use_set_data:
#
# ~/miniconda3/envs/nmt38/lib/python3.8/site-packages/torch/nn/modules/module.py in <lambda>(t)
#     456             Module: self
#     457         """
# --> 458         return self._apply(lambda t: t.cuda(device))
#     459
#     460     def cpu(self: T) -> T:
#
# ~/miniconda3/envs/nmt38/lib/python3.8/site-packages/torch/cuda/__init__.py in _lazy_init()
#     184             raise RuntimeError(
#     185                 "Cannot re-initialize CUDA in forked subprocess. " + msg)
# --> 186         _check_driver()
#     187         if _cudart is None:
#     188             raise AssertionError(
#
# ~/miniconda3/envs/nmt38/lib/python3.8/site-packages/torch/cuda/__init__.py in _check_driver()
#      63         if torch._C._cuda_getDriverVersion() == 0:
#      64             # found no NVIDIA driver on the system
# ---> 65             raise AssertionError("""
#      66 Found no NVIDIA driver on your system. Please check that you
#      67 have an NVIDIA GPU and installed a driver from
#
# AssertionError:
# Found no NVIDIA driver on your system. Please check that you
# have an NVIDIA GPU and installed a driver from
# http://www.nvidia.com/Download/index.aspx

# %%
dir(trg_lang_model)
# Out:
# ['T_destination',
#  '__annotations__',
#  '__call__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_apply',
#  '_backward_hooks',
#  '_buffers',
#  '_call_impl',
#  '_convert_head_mask_to_5d',
#  '_expand_inputs_for_generation',
#  '_force_token_id_to_be_generated',
#  '_forward_hooks',
#  '_forward_pre_hooks',
#  '_forward_unimplemented',
#  '_get_decoder_start_token_id',
#  '_get_logits_processor',
#  '_get_logits_warper',
#  '_get_name',
#  '_get_pad_token_id',
#  '_get_resized_embeddings',
#  '_get_resized_lm_head',
#  '_hook_rss_memory_post_forward',
#  '_hook_rss_memory_pre_forward',
#  '_init_sequence_length_for_generation',
#  '_init_weights',
#  '_keys_to_ignore_on_load_missing',
#  '_keys_to_ignore_on_load_unexpected',
#  '_keys_to_ignore_on_save',
#  '_load_from_state_dict',
#  '_load_state_dict_pre_hooks',
#  '_modules',
#  '_named_members',
#  '_non_persistent_buffers_set',
#  '_parameters',
#  '_prepare_attention_mask_for_generation',
#  '_prepare_decoder_input_ids_for_generation',
#  '_prepare_encoder_decoder_kwargs_for_generation',
#  '_prepare_input_ids_for_generation',
#  '_register_load_state_dict_pre_hook',
#  '_register_state_dict_hook',
#  '_reorder_cache',
#  '_replicate_for_data_parallel',
#  '_resize_final_logits_bias',
#  '_resize_token_embeddings',
#  '_save_to_state_dict',
#  '_slow_forward',
#  '_state_dict_hooks',
#  '_tie_encoder_decoder_weights',
#  '_tie_or_clone_weights',
#  '_update_model_kwargs_for_generation',
#  '_update_seq_length_for_generation',
#  '_version',
#  'add_memory_hooks',
#  'add_module',
#  'adjust_logits_during_generation',
#  'apply',
#  'base_model',
#  'base_model_prefix',
#  'beam_sample',
#  'beam_search',
#  'bfloat16',
#  'buffers',
#  'children',
#  'config',
#  'config_class',
#  'cpu',
#  'cuda',
#  'device',
#  'double',
#  'dtype',
#  'dummy_inputs',
#  'dump_patches',
#  'estimate_tokens',
#  'eval',
#  'extra_repr',
#  'final_logits_bias',
#  'float',
#  'floating_point_ops',
#  'forward',
#  'from_pretrained',
#  'generate',
#  'get_decoder',
#  'get_encoder',
#  'get_extended_attention_mask',
#  'get_head_mask',
#  'get_input_embeddings',
#  'get_output_embeddings',
#  'greedy_search',
#  'group_beam_search',
#  'half',
#  'init_weights',
#  'invert_attention_mask',
#  'is_parallelizable',
#  'lm_head',
#  'load_state_dict',
#  'model',
#  'modules',
#  'name_or_path',
#  'named_buffers',
#  'named_children',
#  'named_modules',
#  'named_parameters',
#  'num_parameters',
#  'parameters',
#  'prepare_inputs_for_generation',
#  'prune_heads',
#  'register_backward_hook',
#  'register_buffer',
#  'register_forward_hook',
#  'register_forward_pre_hook',
#  'register_parameter',
#  'requires_grad_',
#  'reset_memory_hooks_state',
#  'resize_token_embeddings',
#  'sample',
#  'save_pretrained',
#  'set_input_embeddings',
#  'set_output_embeddings',
#  'share_memory',
#  'state_dict',
#  'tie_weights',
#  'to',
#  'train',
#  'training',
#  'type',
#  'zero_grad']

# %%
formatter_fn = lambda txt: f"{txt}"
original_texts = [formatter_fn(txt) for txt in ["i love apple pie"]]

# Tokenize (text to tokens)
tokens = trg_lang_tokenizer.prepare_seq2seq_batch(original_texts, return_tensors='pt')

# %%
dir(tokens)
# Out:
# ['_MutableMapping__marker',
#  '__abstractmethods__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__setattr__',
#  '__setitem__',
#  '__setstate__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_encodings',
#  '_n_sequences',
#  'char_to_token',
#  'char_to_word',
#  'clear',
#  'convert_to_tensors',
#  'copy',
#  'data',
#  'encodings',
#  'fromkeys',
#  'get',
#  'is_fast',
#  'items',
#  'keys',
#  'n_sequences',
#  'pop',
#  'popitem',
#  'sequence_ids',
#  'setdefault',
#  'to',
#  'token_to_chars',
#  'token_to_sequence',
#  'token_to_word',
#  'tokens',
#  'update',
#  'values',
#  'word_ids',
#  'word_to_chars',
#  'word_to_tokens',
#  'words']

# %%
def translate(texts, model, tokenizer, language):
    """Translate texts into a target language"""
    # Format the text as expected by the model
    formatter_fn = lambda txt: f"{txt}" if language == "en" else f">>{language}<< {txt}"
    original_texts = [formatter_fn(txt) for txt in texts]

    # Tokenize (text to tokens)
    tokens = tokenizer.prepare_seq2seq_batch(original_texts, return_tensors='pt')

    # Translate
    translated = model.generate(**tokens)

    # Decode (tokens to text)
    translated_texts = tokenizer.batch_decode(translated, skip_special_tokens=True)

    return translated_texts

# %%
def back_translate(texts, language_src, language_dst):
    """Implements back translation"""
    # Translate from source to target language
    translated = translate(texts, trg_lang_model, trg_lang_tokenizer, language_dst)

    # Translate from target language back to source language
    back_translated = translate(translated, src_lang_model, src_lang_tokenizer, language_src)

    return back_translated

# %%
src_texts = np.array(['I might be late tonight', 'What a movie, so bad', 'That was very kind'])
back_texts = back_translate(src_texts, "en", "es")
