# %%
import pandas as pd
import os
import re
import numpy as np
from sklearn.model_selection import train_test_split
from pathlib import Path

# %%
RANDOM_SEED = 1234
source_data_path = '../../hu-nmt/data/ftp.mokk.bme.hu/Hunglish2/modern.lit/bi'

# %%
# !ls "$source_data_path"
# Out:
# hunglish1.lit.bi  hunglish2.lit.bi

# %% [markdown]
# ## Load the data

# %%
hunglish1_hun = []
hunglish1_eng = []
with open(os.path.join(source_data_path, 'hunglish1.lit.bi'), 'r', encoding='iso-8859-1') as input_file:
    for i, line in enumerate(input_file):
        line_parts = [part.strip() for part in line.split('\t')]
        if len(line_parts) == 2:
            hunglish1_hun.append(line_parts[0])
            hunglish1_eng.append(line_parts[1])
        else:
            print(line_parts)

# %%
data = {
    'hun': hunglish1_hun,
    'eng': hunglish1_eng
}
df1 = pd.DataFrame(data)

# %%
df1
# Out:
#                                                       hun  \
# 0                                                     - -
# 1                                                     - -
# 2                                                     - -
# 3                                                   - ...
# 4                                                       -
# ...                                                   ...
# 449393  Zsuppogott, cuppant és micsongott, ez utóbbit ...
# 449394                             - Zsupsz be! - mondta.
# 449395            - Zsupszkulccsá varázsoltam a serleget.
# 449396  Zsûritagként tökéletes ürügye lenne rá, hogy r...
# 449397                                 - Zsûritag létére?
#
#                                                       eng
# 0                                                       -
# 1                                                       -
# 2                                                       -
# 3                                                     . .
# 4                                                       -
# ...                                                   ...
# 449393  It flolloped, gupped and willomied, doing this...
# 449394                                 "Nabbed!" said he.
# 449395                         "Turned it into a Portkey.
# 449396  It would be an ideal excuse to make regular vi...
# 449397                           "He's one of the judges!
#
# [449398 rows x 2 columns]

# %%
df1['hun_has_letters'] = df1['hun'].apply(lambda sent: any(c.isalpha() for c in sent))
df1['eng_has_letters'] = df1['eng'].apply(lambda sent: any(c.isalpha() for c in sent))

# %%
df1
# Out:
#                                                       hun  \
# 0                                                     - -
# 1                                                     - -
# 2                                                     - -
# 3                                                   - ...
# 4                                                       -
# ...                                                   ...
# 449393  Zsuppogott, cuppant és micsongott, ez utóbbit ...
# 449394                             - Zsupsz be! - mondta.
# 449395            - Zsupszkulccsá varázsoltam a serleget.
# 449396  Zsûritagként tökéletes ürügye lenne rá, hogy r...
# 449397                                 - Zsûritag létére?
#
#                                                       eng  hun_has_letters  \
# 0                                                       -            False
# 1                                                       -            False
# 2                                                       -            False
# 3                                                     . .            False
# 4                                                       -            False
# ...                                                   ...              ...
# 449393  It flolloped, gupped and willomied, doing this...             True
# 449394                                 "Nabbed!" said he.             True
# 449395                         "Turned it into a Portkey.             True
# 449396  It would be an ideal excuse to make regular vi...             True
# 449397                           "He's one of the judges!             True
#
#         eng_has_letters
# 0                 False
# 1                 False
# 2                 False
# 3                 False
# 4                 False
# ...                 ...
# 449393             True
# 449394             True
# 449395             True
# 449396             True
# 449397             True
#
# [449398 rows x 4 columns]

# %%
df1 = df1[df1['hun_has_letters'] & df1['eng_has_letters']]

# %%
df1
# Out:
#                                                       hun  \
# 444     0,1 g ötven órán keresztül, majd 0,2 az áttéré...
# 445     07,00h-kor hivatalosan leváltotta Poole-t a ve...
# 446                                     0903-at mutattak.
# 463                                   10. A CLAVIUS-BÁZIS
# 464                                     10. A HÁBORÚ VÉGE
# ...                                                   ...
# 449393  Zsuppogott, cuppant és micsongott, ez utóbbit ...
# 449394                             - Zsupsz be! - mondta.
# 449395            - Zsupszkulccsá varázsoltam a serleget.
# 449396  Zsûritagként tökéletes ürügye lenne rá, hogy r...
# 449397                                 - Zsûritag létére?
#
#                                                       eng  hun_has_letters  \
# 444     '0.1 gee for fifty hours; then 0.2 until turna...             True
# 445     At 0700 he would officially relieve Poole on t...             True
# 446                                      They read: 0903.             True
# 463                                     10 - Clavius Base             True
# 464                                      10. THE WAR ENDS             True
# ...                                                   ...              ...
# 449393  It flolloped, gupped and willomied, doing this...             True
# 449394                                 "Nabbed!" said he.             True
# 449395                         "Turned it into a Portkey.             True
# 449396  It would be an ideal excuse to make regular vi...             True
# 449397                           "He's one of the judges!             True
#
#         eng_has_letters
# 444                True
# 445                True
# 446                True
# 463                True
# 464                True
# ...                 ...
# 449393             True
# 449394             True
# 449395             True
# 449396             True
# 449397             True
#
# [448236 rows x 4 columns]

# %%
hunglish2_hun = []
hunglish2_eng = []
with open(os.path.join(source_data_path, 'hunglish2.lit.bi'), 'r', encoding='iso-8859-1') as input_file:
    for i, line in enumerate(input_file):
        line_parts = [part.strip() for part in line.split('\t')]
        if len(line_parts) == 2:
            hunglish2_hun.append(line_parts[0])
            hunglish2_eng.append(line_parts[1])
        else:
            print(line_parts)

# %%
data = {
    'hun': hunglish2_hun,
    'eng': hunglish2_eng
}
df2 = pd.DataFrame(data)
df2
# Out:
#                                                        hun  \
# 0        0004-Lima volt már, vagyis éjjel 12 óra 04 per...
# 1                                           - 0, boldogan!
# 2                        0, de milyen igaza volt Akasának!
# 3        - 0, ne légy már ilyen bolond! - kérlelt szelí...
# 4                      0, nem, soha, egyetlen élet sem az!
# ...                                                    ...
# 1220726                   - Zúzott ajka mosolyra húzódott.
# 1220727  Zúzott jég vérmocskos vermébõl kapaszkodott fö...
# 1220728      Zúzott kaméliák hullottak a porhanyós földre.
# 1220729  zz, Vi, egy ujj mászik kifelé a mosdó lefolyój...
# 1220730                                    Zzz brrr csalt!
#
#                                                        eng
# 0         It was now 0004-Lima, or 12:04 A.M., local time.
# 1                                "Oh, I want to," he said.
# 2        Oh, was she ever right, how I had wanted to do...
# 3            "Oh, don't be such a fool," he begged gently.
# 4                             Oh, no, never, not any life!
# ...                                                    ...
# 1220726                Seth's mangled lips formed a smile.
# 1220727  Marius was climbing up out of a bloodstained p...
# 1220728  Camellia blossoms, bruised and falling on the ...
# 1220729  Watch out, Vi, there's a finger coming out of ...
# 1220730                              Zoom - whizz - crash!
#
# [1220731 rows x 2 columns]

# %%
df = pd.concat([df1, df2], ignore_index=True, join='inner')
df = df.drop_duplicates()
df
# Out:
#                                                        hun  \
# 0        0,1 g ötven órán keresztül, majd 0,2 az áttéré...
# 1        07,00h-kor hivatalosan leváltotta Poole-t a ve...
# 2                                        0903-at mutattak.
# 3                                      10. A CLAVIUS-BÁZIS
# 4                                        10. A HÁBORÚ VÉGE
# ...                                                    ...
# 1668962                   - Zúzott ajka mosolyra húzódott.
# 1668963  Zúzott jég vérmocskos vermébõl kapaszkodott fö...
# 1668964      Zúzott kaméliák hullottak a porhanyós földre.
# 1668965  zz, Vi, egy ujj mászik kifelé a mosdó lefolyój...
# 1668966                                    Zzz brrr csalt!
#
#                                                        eng
# 0        '0.1 gee for fifty hours; then 0.2 until turna...
# 1        At 0700 he would officially relieve Poole on t...
# 2                                         They read: 0903.
# 3                                        10 - Clavius Base
# 4                                         10. THE WAR ENDS
# ...                                                    ...
# 1668962                Seth's mangled lips formed a smile.
# 1668963  Marius was climbing up out of a bloodstained p...
# 1668964  Camellia blossoms, bruised and falling on the ...
# 1668965  Watch out, Vi, there's a finger coming out of ...
# 1668966                              Zoom - whizz - crash!
#
# [1613264 rows x 2 columns]

# %% [markdown]
# ## Filter translations

# %%
def filter_by_length(df):
    df.loc[:, 'hun_word_count'] = df['hun'].str.split().apply(len)
    df.loc[:, 'eng_word_count'] = df['eng'].str.split().apply(len)
    return df[(df['hun_word_count'] > 0) &
              (df['hun_word_count'] <= 32) &
              (df['eng_word_count'] > 0) &
              (df['eng_word_count'] <= 32) &
              (
                  ((df['hun_word_count'] - df['eng_word_count']).abs() < 7) |
                  (
                      (df['hun_word_count'] / df['eng_word_count'] < 1.2) &
                      (df['eng_word_count'] / df['hun_word_count'] < 1.2)
                  )
              )
             ]

# %%
df = filter_by_length(df)

# %%
df
# Out:
#                                                        hun  \
# 0        0,1 g ötven órán keresztül, majd 0,2 az áttéré...
# 1        07,00h-kor hivatalosan leváltotta Poole-t a ve...
# 2                                        0903-at mutattak.
# 3                                      10. A CLAVIUS-BÁZIS
# 4                                        10. A HÁBORÚ VÉGE
# ...                                                    ...
# 1668960               Zúzmara lepte az arcát, a szemhéját.
# 1668961                                             Zúzni.
# 1668962                   - Zúzott ajka mosolyra húzódott.
# 1668964      Zúzott kaméliák hullottak a porhanyós földre.
# 1668966                                    Zzz brrr csalt!
#
#                                                        eng  hun_word_count  \
# 0        '0.1 gee for fifty hours; then 0.2 until turna...              14
# 1        At 0700 he would officially relieve Poole on t...              14
# 2                                         They read: 0903.               2
# 3                                        10 - Clavius Base               3
# 4                                         10. THE WAR ENDS               4
# ...                                                    ...             ...
# 1668960               Frost covered her face, her eyelids.               6
# 1668961                                             Blast.               1
# 1668962                Seth's mangled lips formed a smile.               5
# 1668964  Camellia blossoms, bruised and falling on the ...               6
# 1668966                              Zoom - whizz - crash!               3
#
#          eng_word_count
# 0                    17
# 1                    20
# 2                     3
# 3                     4
# 4                     4
# ...                 ...
# 1668960               6
# 1668961               1
# 1668962               6
# 1668964               9
# 1668966               5
#
# [1414171 rows x 4 columns]

# %% [markdown]
# ## Remove translations that are in other test sets

# %%
main_test_set_path_hun = '../../data/Hunglish2/combined-32-simple/hunglish2-test.hu'
main_test_set_path_eng = '../../data/Hunglish2/combined-32-simple/hunglish2-test.en'

# %%
hun_sentences = []
eng_sentences = []
with open(main_test_set_path_hun, 'r') as hun_file:
    with open(main_test_set_path_eng, 'r') as eng_file:
        for hun_line, eng_line in zip(hun_file, eng_file):
            hun_sentences.append(hun_line.strip())
            eng_sentences.append(eng_line.strip())
            
data = {
    'hun': hun_sentences,
    'eng': eng_sentences
}
df_main_test = pd.DataFrame(data)

# %%
df_main_test
# Out:
#                                                      hun  \
# 0               Ha azt hiszik, hogy ők használnak téged.
# 1                           Nem várta őket kocsi, semmi.
# 2                 Miért nem próbálkozik más bánásmóddal?
# 3      (Amint Henry lehajol, hogy megcsókolja, Higgin...
# 4            A víztől mindenképpen zárlatos lesz majd...
# ...                                                  ...
# 21725                         Ne keverd a sört a borral!
# 21726                               -Nemsokára meglátod.
# 21727                                Göringnek dolgozik?
# 21728  Frankón, a lúzer-tüsszentés már hivatalosan ha...
# 21729                           Előkészíti az érkezését.
#
#                                                      eng
# 0                   Only if they think theyre using you.
# 1                               No carriage was waiting.
# 2               Why not give them a change of treatment?
# 3      [As he bends to kiss her, she takes his hat of...
# 4                             Water should short it out.
# ...                                                  ...
# 21725                      Dont mix beer and wine, ever!
# 21726                                     -Youll see it.
# 21727                                        For Göring?
# 21728  Im pretty sure the loser sneeze is officially ...
# 21729                         He will make his entrance.
#
# [21730 rows x 2 columns]

# %%
df_ones_in_main_test = pd.merge(df, df_main_test, indicator=True, how='outer').query('_merge=="both"').drop('_merge', axis=1)
df_ones_in_main_test
# Out:
#                                                        hun  \
# 151      1832-ben a párizsi szennycsatorna még korántse...
# 504                                             8. fejezet
# 598                                                     Á!
# 1253     A báró még mindig hátat fordított a grófnak, b...
# 1296            A baronet keze hideg volt, mint a márvány.
# ...                                                    ...
# 1410998  Will is, Lyra is reszketett, félelem, kimerült...
# 1412616  Zajcev elhagyta az irodát, és a liftek felé in...
# 1413215   Zenobia nem nézett a szemembe, a semmibe bámult.
# 1413317  Zihálva ültem fel, veríték csorgott az arcomon...
# 1413671     Zümmögéssé olvadtak össze a lakás apró neszei.
#
#                                                        eng  hun_word_count  \
# 151      The sewers of Paris in 1832 were far from bein...            10.0
# 504                                              Chapter 8             2.0
# 598                                                    Ah.             1.0
# 1253        The Baron kept his back to the Count, nodding.             9.0
# 1296                  It was as cold as a block of marble.             8.0
# ...                                                    ...             ...
# 1410998  Will and Lyra were both trembling and weak wit...            19.0
# 1412616  Zaitzev walked out and down the corridor to th...             9.0
# 1413215       She stared before her, but not into my eyes.             8.0
# 1413317  I sat, panting, the sweat pouring down my face...            19.0
# 1413671    All the little sounds of the flat became a hum.             7.0
#
#          eng_word_count
# 151                14.0
# 504                 2.0
# 598                 1.0
# 1253                9.0
# 1296                9.0
# ...                 ...
# 1410998            19.0
# 1412616            10.0
# 1413215             9.0
# 1413317            22.0
# 1413671            10.0
#
# [2874 rows x 4 columns]

# %%
df_ones_in_main_test.shape[0] / df.shape[0]
# Out:
# 0.0020322860531010747

# %%
df_without_main_test = pd.merge(df, df_main_test, indicator=True, how='outer').query('_merge=="left_only"').drop('_merge', axis=1)
df_without_main_test
# Out:
#                                                        hun  \
# 0        0,1 g ötven órán keresztül, majd 0,2 az áttéré...
# 1        07,00h-kor hivatalosan leváltotta Poole-t a ve...
# 2                                        0903-at mutattak.
# 3                                      10. A CLAVIUS-BÁZIS
# 4                                        10. A HÁBORÚ VÉGE
# ...                                                    ...
# 1414414               Zúzmara lepte az arcát, a szemhéját.
# 1414415                                             Zúzni.
# 1414416                   - Zúzott ajka mosolyra húzódott.
# 1414417      Zúzott kaméliák hullottak a porhanyós földre.
# 1414418                                    Zzz brrr csalt!
#
#                                                        eng  hun_word_count  \
# 0        '0.1 gee for fifty hours; then 0.2 until turna...            14.0
# 1        At 0700 he would officially relieve Poole on t...            14.0
# 2                                         They read: 0903.             2.0
# 3                                        10 - Clavius Base             3.0
# 4                                         10. THE WAR ENDS             4.0
# ...                                                    ...             ...
# 1414414               Frost covered her face, her eyelids.             6.0
# 1414415                                             Blast.             1.0
# 1414416                Seth's mangled lips formed a smile.             5.0
# 1414417  Camellia blossoms, bruised and falling on the ...             6.0
# 1414418                              Zoom - whizz - crash!             3.0
#
#          eng_word_count
# 0                  17.0
# 1                  20.0
# 2                   3.0
# 3                   4.0
# 4                   4.0
# ...                 ...
# 1414414             6.0
# 1414415             1.0
# 1414416             6.0
# 1414417             9.0
# 1414418             5.0
#
# [1411545 rows x 4 columns]

# %%
def get_basic_stats(df, col):
    metric_dict = {}
    metric_dict['q0.25'] = str(df[col].quantile(q=0.25))
    metric_dict['q0.5'] = str(df[col].quantile(q=0.5))
    metric_dict['q0.75'] = str(df[col].quantile(q=0.75))
    metric_dict['q0.99'] = str(df[col].quantile(q=0.99))
    metric_dict['q0.999'] = str(df[col].quantile(q=0.999))
    metric_dict['min'] = str(df[col].min())
    metric_dict['max'] = str(df[col].max())
    metric_dict['mean'] = str(df[col].mean())
    metric_dict['stdev'] = str(df[col].std())
    
    return metric_dict

# %%
get_basic_stats(df_without_main_test, 'hun_word_count')
# Out:
# {'q0.25': '4.0',
#  'q0.5': '7.0',
#  'q0.75': '11.0',
#  'q0.99': '26.0',
#  'q0.999': '31.0',
#  'min': '1.0',
#  'max': '32.0',
#  'mean': '8.620396090808299',
#  'stdev': '5.6186232364479'}

# %%
get_basic_stats(df_without_main_test, 'eng_word_count')
# Out:
# {'q0.25': '5.0',
#  'q0.5': '9.0',
#  'q0.75': '14.0',
#  'q0.99': '29.0',
#  'q0.999': '32.0',
#  'min': '1.0',
#  'max': '32.0',
#  'mean': '10.047593948474898',
#  'stdev': '6.251214670365017'}

# %% [markdown]
# ## Sample data

# %%
def sample(df, size, output_path, output_prefix):
    valid_size = size * 0.15
    
    np.random.seed(RANDOM_SEED)
    nums = np.random.choice(np.arange(df_without_main_test.shape[0]), size)
    sampled_df = df.iloc[nums].reset_index()
    
    train_idxs, valid_idxs = train_test_split(np.arange(size), test_size=int(valid_size), random_state=RANDOM_SEED)
    indices = {
        'train': train_idxs,
        'valid': valid_idxs
    }
    
    Path(output_path).mkdir(parents=True, exist_ok=True)
    for set_type in ['train', 'valid']:
        with open(os.path.join(output_path, f'{output_prefix}-{set_type}.hu'), 'w') as hun_file:
            with open(os.path.join(output_path, f'{output_prefix}-{set_type}.en'), 'w') as eng_file:
                for row in sampled_df.iloc[indices[set_type]].iterrows():
                    hun_file.write(row[1][1])
                    hun_file.write('\n')
                    eng_file.write(row[1][2])
                    eng_file.write('\n')

# %%
low_resource_path = '../../data/Hunglish2/low-resource'

# %%
for sample_count in [75, 100, 200, 300, 400, 500]:
    sample(df_without_main_test, sample_count * 1000, low_resource_path, f'hunglish2-{sample_count}k')

# %% [markdown]
# ## Save test data

# %%
with open(os.path.join(low_resource_path, 'hunglish2-test.hu'), 'w') as hun_file:
    with open(os.path.join(low_resource_path, 'hunglish2-test.en'), 'w') as eng_file:
        for row in df_ones_in_main_test.iterrows():
            hun_file.write(row[1][0])
            hun_file.write('\n')
            eng_file.write(row[1][1])
            eng_file.write('\n')
